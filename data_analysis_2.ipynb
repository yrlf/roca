# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# local

# %%
# read the whole experiment results
#df = pd.read_csv("./results/results_results_new_alldata_COMBINED_210123.csv")
#df = pd.read_csv("./results/results_xyguassian_200_20000.csv")
# 3
df=pd.read_csv("./results/results_all_instance_injection.csv.csv")

# %%
df[df['dataset']=='xyguassian200']
# Out:
#       noisy_rate  error_rate        dataset noise_type  causal  inital_noise  \
# 2151         0.1       0.505  xyguassian200        sym       0          0.01
# 2152         0.2       0.505  xyguassian200        sym       0          0.01
# 2153         0.3       0.475  xyguassian200        sym       0          0.01
# 2154         0.4       0.475  xyguassian200        sym       0          0.01
# 2155         0.5       0.520  xyguassian200        sym       0          0.01
# ...          ...         ...            ...        ...     ...           ...
# 4288         0.5       0.520  xyguassian200       pair       0          0.30
# 4289         0.6       0.475  xyguassian200       pair       0          0.30
# 4290         0.7       0.495  xyguassian200       pair       0          0.30
# 4291         0.8       0.520  xyguassian200       pair       0          0.30
# 4292         0.9       0.520  xyguassian200       pair       0          0.30
#
#       seed
# 2151     1
# 2152     1
# 2153     1
# 2154     1
# 2155     1
# ...    ...
# 4288     5
# 4289     5
# 4290     5
# 4291     5
# 4292     5
#
# [1062 rows x 7 columns]

# %%
# group by to calculate mean and std of error rate
df2=df.groupby(["dataset","noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
df2=df2['error_rate']
df2
# Out:
#                                                       mean       std
# dataset        noise_type inital_noise noisy_rate
# xyguassian     instance   0.01         0.1         0.49992  0.001148
#                                        0.2         0.49940  0.002360
#                                        0.3         0.50143  0.002399
#                                        0.4         0.50085  0.004261
#                                        0.5         0.49810  0.003674
# ...                                                    ...       ...
# yxguassian5000 sym        0.30         0.5         0.50360  0.006775
#                                        0.6         0.53144  0.007648
#                                        0.7         0.56152  0.006703
#                                        0.8         0.59032  0.005887
#                                        0.9         0.61880  0.002332
#
# [972 rows x 2 columns]

# %%
# save csv file according to dataset
#dataset_names = ["xyguassian", "yxguassian", "balancescale", "krkp", "waveform", "splice", "cifar10", "cifar10n_worst", "cifar10n_aggre", "cifar10n_random1", "cifar10n_random2", "cifar10n_random3"]
#dataset_names = ['xyguassian', 'yxguassian']#, 'balancescale', 'krkp', 'waveform', 'splice']

dataset_names=['breastcancer', 'wdbc', 'iris', 'letter', 'mushroom', 'segment',
       'sonar', 'vowel', 'xyguassian', 'yxguassian', 'balancescale',
       'krkp', 'waveform', 'splice', 'g241n', 'g241c','digit1', 'usps', 'coil',
       'coil2', 'bci', 'secstr', 'cifar10', 'splice2balance','splice2imbalance', 'xyguassian100','xyguassian200','xyguassian500','xyguassian1000','xyguassian5000','yxguassian200','yxguassian1000','yxguassian5000']

for name in dataset_names:
    path = './results/csv/'+name +'_groupby2_newDataCombined.csv'
    df_temp = df[df['dataset']==name]
    df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
    df_temp = df_temp['error_rate']
    print(path)
    df_temp.to_csv(path)
# Out:
# ./results/csv/breastcancer_groupby2_newDataCombined.csv
# ./results/csv/wdbc_groupby2_newDataCombined.csv
# ./results/csv/iris_groupby2_newDataCombined.csv
# ./results/csv/letter_groupby2_newDataCombined.csv
# ./results/csv/mushroom_groupby2_newDataCombined.csv
# ./results/csv/segment_groupby2_newDataCombined.csv
# ./results/csv/sonar_groupby2_newDataCombined.csv
# ./results/csv/vowel_groupby2_newDataCombined.csv
# ./results/csv/xyguassian_groupby2_newDataCombined.csv
# ./results/csv/yxguassian_groupby2_newDataCombined.csv
# ./results/csv/balancescale_groupby2_newDataCombined.csv
# ./results/csv/krkp_groupby2_newDataCombined.csv
# ./results/csv/waveform_groupby2_newDataCombined.csv
# ./results/csv/splice_groupby2_newDataCombined.csv
# ./results/csv/g241n_groupby2_newDataCombined.csv
# ./results/csv/g241c_groupby2_newDataCombined.csv
# ./results/csv/digit1_groupby2_newDataCombined.csv
# ./results/csv/usps_groupby2_newDataCombined.csv
# ./results/csv/coil_groupby2_newDataCombined.csv
# ./results/csv/coil2_groupby2_newDataCombined.csv
# ./results/csv/bci_groupby2_newDataCombined.csv
# ./results/csv/secstr_groupby2_newDataCombined.csv
# ./results/csv/cifar10_groupby2_newDataCombined.csv
# ./results/csv/splice2balance_groupby2_newDataCombined.csv
# ./results/csv/splice2imbalance_groupby2_newDataCombined.csv
# ./results/csv/xyguassian100_groupby2_newDataCombined.csv
# ./results/csv/xyguassian200_groupby2_newDataCombined.csv
# ./results/csv/xyguassian500_groupby2_newDataCombined.csv
# ./results/csv/xyguassian1000_groupby2_newDataCombined.csv
# ./results/csv/xyguassian5000_groupby2_newDataCombined.csv
# ./results/csv/yxguassian200_groupby2_newDataCombined.csv
# ./results/csv/yxguassian1000_groupby2_newDataCombined.csv
# ./results/csv/yxguassian5000_groupby2_newDataCombined.csv
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])
# /var/folders/z8/zm1gct552gb8700n_kq3pm9h0000gn/T/ipykernel_32610/2396001854.py:13: FutureWarning: ['dataset'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_temp = df_temp.groupby(["noise_type","inital_noise","noisy_rate"]).agg([np.mean, np.std])

# %%
# from asyncio import threads
from operator import contains
import scipy.stats as st

from matplotlib.ticker import FormatStrFormatter


corr_table = pd.DataFrame(columns=['dataset','noise_type','initial_noise','slope','stderr','corr','threshold','p_value'])
#dataset_names = ["krkp","xyguassian","yxguassian", "balancescale", "krkp", "waveform", "splice", "cifar10", "cifar10n_worst", "cifar10n_aggre", "cifar10n_random1", "cifar10n_random2", "cifar10n_random3"]
# ]#,
#dataset_names=['breastcancer', 'wdbc', 'iris', 'letter', 'mushroom', 'segment',
        # 'sonar', 'vowel', 'xyguassian', 'yxguassian', 'balancescale',
        # 'krkp', 'waveform', 'splice', 'g241n','g241c', 'digit1', 'usps', 'coil',
        # 'coil2', 'bci', 'secstr', 'cifar10']

#dataset_names = ["xyguassian","yxguassian"]
#dataset_names = ['xyguassian200','yxguassian200','xyguassian1000','yxguassian1000','xyguassian5000','yxguassian5000','xyguassian','yxguassian']
dataset_names=['breastcancer' ,'wdbc',  'iris','letter', 'mushroom','segment', 'sonar', 'vowel',"krkp","xyguassian","yxguassian", "balancescale", "krkp", "waveform", "splice"]

#"cifar10", "cifar10n_worst", "cifar10n_aggre", "cifar10n_random1", "cifar10n_random2", "cifar10n_random3"]  #

#'cholesterol',hepatitis

def generate_plot_individual(dataset_name, df, corr_table, threshold=0.1):
    

    name_dict ={'yxguassian':'synAnticausal','xyguassian':'synCausal','balancescale':'BalanceScale','krkp':'KRKP','waveform':'Waveform','splice':'Splice','cifar10':'CIFAR10','cifar10n_worst':'CIFAR10N_worst','cifar10n_aggre':'CIFAR10N_aggre','cifar10n_random1':'CIFAR10N_random1','cifar10n_random2':'CIFAR10N_random2','cifar10n_random3':'CIFAR10N_random3','breastcancer':'BreastCancer','cholesterol':'Cholesterol','wdbc':'WDBC','hepatitis':'Hepatitis','iris':'Iris','letter':'Letter','mushroom':'Mushroom','segment':'Segment','sonar':'Sonar','vowel':'Vowel','g241c':'G241c','g241n':'G241n','digit1':'Digit1','usps':'Usps','coil':'Coil','coil2':'Coil2','bci':'BCI','secstr':'Secstr','splice2balance':'Splice2B','splice2imbalance':'Splice2IMBA','xyguassian100':'xy100','xyguassian200':'synCausal','xyguassian500':'xy500','xyguassian1000':'xy1000','xyguassian5000':'xy5000','yxguassian200':'synAnticausal','yxguassian1000':'yx1000','yxguassian5000':'yx5000'}

    noise_dict = {'sym':'Sym','pair':'Pair','instance':'Ins'}
    noise_type_list = ["instance","sym","pair"]
    initial_noise_list = [0.01, 0.1, 0.2, 0.3]
    if dataset_name == 'xyguassian':
        linecolor = "blue"
    else:
        linecolor = "red"
    print("dataset_name:"+dataset_name)
    for noise_type in noise_type_list:
        for initial_noise in initial_noise_list:
    
            df_temp = df[(df['noise_type']==noise_type) & (df['inital_noise']==initial_noise)]
            x=df_temp['noisy_rate']
            y =df_temp['mean']
            
            y_std = df_temp['std']

            # Define the confidence interval
            ci = 0.1 * y_std / y
            # calculate correlation coefficient
            corr = np.corrcoef(x, y)[0, 1]
            # regression
            slope, intercept, r_value, p_value, std_err = st.linregress(x, y)
            
            # upper bound of slope at 95% confidence interval
            slope_upper = slope + 1.96 * std_err
            # lower bound of slope at 95% confidence interval
            slope_lower = slope - 1.96 * std_err

            # t-test for slope
            alpha = 0.05

            # one-tail t-test for slope left side test:

            # H0: slope >= 0.05
            # H1: slope < 0.05
            t1 = (slope - threshold) / std_err
            # single side t-test for t1
            
            p1 = st.t.cdf(t1, df_temp.shape[0] - 1)


            # one-tail t-test for slope right side test
            
            # H0: slope <= -0.05
            # H1: slope > -0.05
            t2 = (slope - -threshold)/ std_err
            # single side t-test for t2
            p2 = 1-st.t.cdf(t2, df_temp.shape[0] - 1)
            maxp = max(p1, p2)
            #print("alpha/2:", alpha/2.0)
            print(maxp)
            # if max(p1,p2) < alpha/2.0 :
            #     output = "reject H0, slope <0.05 and >-0.05"                
            # else:
            #     output="cannot reject H0"
            output = ""
            print(output)

            plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

            y_pred = slope * x + intercept

            # Plot the sinus function
            # plot scatter
            
            #plt.plot(x, y_pred,'--', 'r', label='fitted line')
            
            plt.plot(x, y,'*', color=linecolor)
            plt.plot(x,y,'-',color=linecolor)
            #plt.scatter(x, y, label=noise_type)     
            #plt.plot(x,y)
            plt.ylim(0,1)
            # round y axis to 2 decimal places
            
            # print the slope with 2 decimal places

            #print(f"slope: {slope:.2f}")
            # s = f"slope: {slope:.4f}"
            # if slope_upper>threshold or slope_lower<-threshold:
            #     output = s+"\nthe 95% CI of slope is out of the range ["+str(-threshold) +","+str(threshold)+"]"
            # else:
            #     output = s+"\nthe 95% CI  of slope is within the range ["+str(-threshold)+","+str(threshold)+"]"

            
                        
            #print('r-squared: '+str(round(r_value**2,4))+'\np-value: '+str(round(p_value,6))+'\nslope: '+str(round(slope,4)))
            #plt.text(0.1, 0.5, 'r-squared: '+str(round(r_value**2,4))+'\np-value: '+str(round(p_value,6))+'\nslope: '+str(round(slope,4)), fontsize=12)
           
            #plt.axis.set_major_formatter(FormatStrFormatter('%g'))
            plt.rcParams.update({'font.size': 18})
            plt.xlabel('Noise Level')
            plt.ylabel('Disagreement')
            plt.xlim(0,1)

            if initial_noise == 0.01:
                initial_noise = 0

            plt.title("(" +name_dict[dataset_name]+", "+noise_dict[noise_type]+"-"+ str(initial_noise*100) +"%)"+output)
            
            # Plot the confidence interval
            str_maxp= "{:.4f}".format(maxp)
            print(str_maxp)
            plt.text(0.1, 0.6, '\np-value: '+str_maxp+'\nslope: '+str(round(slope,4)), fontsize=18)
            plt.fill_between(x, (y-ci), (y+ci), color=linecolor, alpha=0.2)
            plt.tight_layout(pad=0, w_pad=0, h_pad=0)
            plt.savefig('./results/pdf/newXYandYX/'+dataset_name+'_'+noise_type+'_'+str(initial_noise)+'.pdf',bbox_inches='tight')
            # increase font size of title and axis
            

            #plt.show()
            #df_corr_temp= pd.DataFrame([[dataset_name, noise_type, initial_noise, corr]], columns=['dataset','noise_type','initial_noise','corr'])
            corr_table.loc[len(corr_table)] = [dataset_name, noise_type, initial_noise, slope,std_err, corr, threshold,str_maxp]
            plt.close()
            
corr_table_total = pd.DataFrame(columns=['dataset','noise_type','initial_noise','slope','stderr','corr','threshold','p_value'])
threshold_list = [0.1, 0.09, 0.08, 0.07, 0.06, 0.05, 0.04, 0.03, 0.02, 0.01, 0.005]
#threshold_list = [0.1]
for name in dataset_names:
    if (contains(name, 'cifar10n')==False):
    
        #df = pd.read_csv("./results/csv/"+name +'_groupby2.csv')
        df = pd.read_csv("./results/csv/"+name +'_groupby2_newDataCombined.csv')
        for threshold2 in threshold_list:
            generate_plot_individual(name, df, corr_table,threshold=threshold2)
            corr_table_total=pd.concat([corr_table_total, corr_table])
# Out:
# dataset_name:breastcancer
# 0.0008700692142257194
#
# 0.0009
# 0.0008700692142257194
#
# 0.0009
# 0.0008700692142257194
#
# 0.0009
# 3.0953131897947292e-06
#
# 0.0000
# 0.0008700692142257194
#
# 0.0009
# 5.7991869815458335e-05
#
# 0.0001
# 0.00011310004722928922
#
# 0.0001
# 0.00011310004722928922
#
# 0.0001
# 0.009619132476497422
#
# 0.0096
# 5.7991869815458335e-05
#
# 0.0001
# 0.00011310004722928922
#
# 0.0001
# 0.00011310004722928922
#
# 0.0001
# dataset_name:breastcancer
# 0.011865739078147862
#
# 0.0119
# 0.011865739078147862
#
# 0.0119
# 0.011865739078147862
#
# 0.0119
# 9.381161842733895e-06
#
# 0.0000
# 0.011865739078147862
#
# 0.0119
# 0.00018899758790254478
#
# 0.0002
# 0.0002650039862249454
#
# 0.0003
# 0.0002650039862249454
#
# 0.0003
# 0.11333711690146059
#
# 0.1133
# 0.00018899758790254478
#
# 0.0002
# 0.0002650039862249454
#
# 0.0003
# 0.0002650039862249454
#
# 0.0003
# dataset_name:breastcancer
# 0.18168585894082073
#
# 0.1817
# 0.18168585894082073
#
# 0.1817
# 0.18168585894082073
#
# 0.1817
# 3.3384191107245965e-05
#
# 0.0000
# 0.18168585894082073
#
# 0.1817
# 0.0007212571388910699
#
# 0.0007
# 0.0006706405772330014
#
# 0.0007
# 0.0006706405772330014
#
# 0.0007
# 0.615011802831977
#
# 0.6150
# 0.0007212571388910699
#
# 0.0007
# 0.0006706405772330014
#
# 0.0007
# 0.0006706405772330014
#
# 0.0007
# dataset_name:breastcancer
# 0.7919817603154582
#
# 0.7920
# 0.7919817603154582
#
# 0.7920
# 0.7919817603154582
#
# 0.7920
# 0.00014581772922556244
#
# 0.0001
# 0.7919817603154582
#
# 0.7920
# 0.003285685505645708
#
# 0.0033
# 0.0018444745831019916
#
# 0.0018
# 0.0018444745831019916
#
# 0.0018
# 0.9540662143113973
#
# 0.9541
# 0.003285685505645708
#
# 0.0033
# 0.0018444745831019916
#
# 0.0018
# 0.0018444745831019916
#
# 0.0018
# dataset_name:breastcancer
# 0.9860176554154093
#
# 0.9860
# 0.9860176554154093
#
# 0.9860
# 0.9860176554154093
#
# 0.9860
# 0.0008250758630829045
#
# 0.0008
# 0.9860176554154093
#
# 0.9860
# 0.017566819591305016
#
# 0.0176
# 0.005512064149422618
#
# 0.0055
# 0.005512064149422618
#
# 0.0055
# 0.99611601102041
#
# 0.9961
# 0.017566819591305016
#
# 0.0176
# 0.005512064149422618
#
# 0.0055
# 0.005512064149422618
#
# 0.0055
# dataset_name:breastcancer
# 0.9989996943175837
#
# 0.9990
# 0.9989996943175837
#
# 0.9990
# 0.9989996943175837
#
# 0.9990
# 0.006290575499557055
#
# 0.0063
# 0.9989996943175837
#
# 0.9990
# 0.09632641328801697
#
# 0.0963
# 0.017609297415084775
#
# 0.0176
# 0.017609297415084775
#
# 0.0176
# 0.9995568787231023
#
# 0.9996
# 0.09632641328801697
#
# 0.0963
# 0.017609297415084775
#
# 0.0176
# 0.017609297415084775
#
# 0.0176
# dataset_name:breastcancer
# 0.9998863314336979
#
# 0.9999
# 0.9998863314336979
#
# 0.9999
# 0.9998863314336979
#
# 0.9999
# 0.05859233494343772
#
# 0.0586
# 0.9998863314336979
#
# 0.9999
# 0.38115296299901474
#
# 0.3812
# 0.057214709294850855
#
# 0.0572
# 0.057214709294850855
#
# 0.0572
# 0.9999275575361155
#
# 0.9999
# 0.38115296299901474
#
# 0.3812
# 0.057214709294850855
#
# 0.0572
# 0.057214709294850855
#
# 0.0572
# dataset_name:breastcancer
# 0.9999807924324616
#
# 1.0000
# 0.9999807924324616
#
# 1.0000
# 0.9999807924324616
#
# 1.0000
# 0.38222138383653936
#
# 0.3822
# 0.9999807924324616
#
# 1.0000
# 0.7756769848963924
#
# 0.7757
# 0.17052144371408903
#
# 0.1705
# 0.17052144371408903
#
# 0.1705
# 0.9999841619680971
#
# 1.0000
# 0.7756769848963924
#
# 0.7757
# 0.17052144371408903
#
# 0.1705
# 0.17052144371408903
#
# 0.1705
# dataset_name:breastcancer
# 0.9999956431068118
#
# 1.0000
# 0.9999956431068118
#
# 1.0000
# 0.9999956431068118
#
# 1.0000
# 0.855529183257183
#
# 0.8555
# 0.9999956431068118
#
# 1.0000
# 0.9534684043943824
#
# 0.9535
# 0.4032989686827104
#
# 0.4033
# 0.4032989686827104
#
# 0.4033
# 0.9999956773053125
#
# 1.0000
# 0.9534684043943824
#
# 0.9535
# 0.4032989686827104
#
# 0.4033
# 0.4032989686827104
#
# 0.4033
# dataset_name:breastcancer
# 0.9999987709574946
#
# 1.0000
# 0.9999987709574946
#
# 1.0000
# 0.9999987709574946
#
# 1.0000
# 0.9837308345358711
#
# 0.9837
# 0.9999987709574946
#
# 1.0000
# 0.9916684891460726
#
# 0.9917
# 0.6867938766727342
#
# 0.6868
# 0.6867938766727342
#
# 0.6868
# 0.9999986013350476
#
# 1.0000
# 0.9916684891460726
#
# 0.9917
# 0.6867938766727342
#
# 0.6868
# 0.6867938766727342
#
# 0.6868
# dataset_name:breastcancer
# 0.9999993036912629
#
# 1.0000
# 0.9999993036912629
#
# 1.0000
# 0.9999993036912629
#
# 1.0000
# 0.994606375598229
#
# 0.9946
# 0.9999993036912629
#
# 1.0000
# 0.9963569760142994
#
# 0.9964
# 0.7992004337696773
#
# 0.7992
# 0.7992004337696773
#
# 0.7992
# 0.9999991621362745
#
# 1.0000
# 0.9963569760142994
#
# 0.9964
# 0.7992004337696773
#
# 0.7992
# 0.7992004337696773
#
# 0.7992
# dataset_name:wdbc
# 0.999999999980314
#
# 1.0000
# 0.999999999980314
#
# 1.0000
# 0.999999999980314
#
# 1.0000
# 0.999999999980314
#
# 1.0000
# 0.999999999980314
#
# 1.0000
# 0.999999999980314
#
# 1.0000
# 0.999999999980314
#
# 1.0000
# 0.999999999980314
#
# 1.0000
# 0.999999999980314
#
# 1.0000
# 0.999999999980314
#
# 1.0000
# 0.999999999980314
#
# 1.0000
# 0.999999999980314
#
# 1.0000
# dataset_name:wdbc
# 0.9999999999828194
#
# 1.0000
# 0.9999999999828194
#
# 1.0000
# 0.9999999999828194
#
# 1.0000
# 0.9999999999828194
#
# 1.0000
# 0.9999999999828194
#
# 1.0000
# 0.9999999999828194
#
# 1.0000
# 0.9999999999828194
#
# 1.0000
# 0.9999999999828194
#
# 1.0000
# 0.9999999999828194
#
# 1.0000
# 0.9999999999828194
#
# 1.0000
# 0.9999999999828194
#
# 1.0000
# 0.9999999999828194
#
# 1.0000
# dataset_name:wdbc
# 0.9999999999849718
#
# 1.0000
# 0.9999999999849718
#
# 1.0000
# 0.9999999999849718
#
# 1.0000
# 0.9999999999849718
#
# 1.0000
# 0.9999999999849718
#
# 1.0000
# 0.9999999999849718
#
# 1.0000
# 0.9999999999849718
#
# 1.0000
# 0.9999999999849718
#
# 1.0000
# 0.9999999999849718
#
# 1.0000
# 0.9999999999849718
#
# 1.0000
# 0.9999999999849718
#
# 1.0000
# 0.9999999999849718
#
# 1.0000
# dataset_name:wdbc
# 0.9999999999868256
#
# 1.0000
# 0.9999999999868256
#
# 1.0000
# 0.9999999999868256
#
# 1.0000
# 0.9999999999868256
#
# 1.0000
# 0.9999999999868256
#
# 1.0000
# 0.9999999999868256
#
# 1.0000
# 0.9999999999868256
#
# 1.0000
# 0.9999999999868256
#
# 1.0000
# 0.9999999999868256
#
# 1.0000
# 0.9999999999868256
#
# 1.0000
# 0.9999999999868256
#
# 1.0000
# 0.9999999999868256
#
# 1.0000
# dataset_name:wdbc
# 0.9999999999884263
#
# 1.0000
# 0.9999999999884263
#
# 1.0000
# 0.9999999999884263
#
# 1.0000
# 0.9999999999884263
#
# 1.0000
# 0.9999999999884263
#
# 1.0000
# 0.9999999999884263
#
# 1.0000
# 0.9999999999884263
#
# 1.0000
# 0.9999999999884263
#
# 1.0000
# 0.9999999999884263
#
# 1.0000
# 0.9999999999884263
#
# 1.0000
# 0.9999999999884263
#
# 1.0000
# 0.9999999999884263
#
# 1.0000
# dataset_name:wdbc
# 0.9999999999898115
#
# 1.0000
# 0.9999999999898115
#
# 1.0000
# 0.9999999999898115
#
# 1.0000
# 0.9999999999898115
#
# 1.0000
# 0.9999999999898115
#
# 1.0000
# 0.9999999999898115
#
# 1.0000
# 0.9999999999898115
#
# 1.0000
# 0.9999999999898115
#
# 1.0000
# 0.9999999999898115
#
# 1.0000
# 0.9999999999898115
#
# 1.0000
# 0.9999999999898115
#
# 1.0000
# 0.9999999999898115
#
# 1.0000
# dataset_name:wdbc
# 0.9999999999910131
#
# 1.0000
# 0.9999999999910131
#
# 1.0000
# 0.9999999999910131
#
# 1.0000
# 0.9999999999910131
#
# 1.0000
# 0.9999999999910131
#
# 1.0000
# 0.9999999999910131
#
# 1.0000
# 0.9999999999910131
#
# 1.0000
# 0.9999999999910131
#
# 1.0000
# 0.9999999999910131
#
# 1.0000
# 0.9999999999910131
#
# 1.0000
# 0.9999999999910131
#
# 1.0000
# 0.9999999999910131
#
# 1.0000
# dataset_name:wdbc
# 0.9999999999920575
#
# 1.0000
# 0.9999999999920575
#
# 1.0000
# 0.9999999999920575
#
# 1.0000
# 0.9999999999920575
#
# 1.0000
# 0.9999999999920575
#
# 1.0000
# 0.9999999999920575
#
# 1.0000
# 0.9999999999920575
#
# 1.0000
# 0.9999999999920575
#
# 1.0000
# 0.9999999999920575
#
# 1.0000
# 0.9999999999920575
#
# 1.0000
# 0.9999999999920575
#
# 1.0000
# 0.9999999999920575
#
# 1.0000
# dataset_name:wdbc
# 0.9999999999929674
#
# 1.0000
# 0.9999999999929674
#
# 1.0000
# 0.9999999999929674
#
# 1.0000
# 0.9999999999929674
#
# 1.0000
# 0.9999999999929674
#
# 1.0000
# 0.9999999999929674
#
# 1.0000
# 0.9999999999929674
#
# 1.0000
# 0.9999999999929674
#
# 1.0000
# 0.9999999999929674
#
# 1.0000
# 0.9999999999929674
#
# 1.0000
# 0.9999999999929674
#
# 1.0000
# 0.9999999999929674
#
# 1.0000
# dataset_name:wdbc
# 0.9999999999937618
#
# 1.0000
# 0.9999999999937618
#
# 1.0000
# 0.9999999999937618
#
# 1.0000
# 0.9999999999937618
#
# 1.0000
# 0.9999999999937618
#
# 1.0000
# 0.9999999999937618
#
# 1.0000
# 0.9999999999937618
#
# 1.0000
# 0.9999999999937618
#
# 1.0000
# 0.9999999999937618
#
# 1.0000
# 0.9999999999937618
#
# 1.0000
# 0.9999999999937618
#
# 1.0000
# 0.9999999999937618
#
# 1.0000
# dataset_name:wdbc
# 0.9999999999941207
#
# 1.0000
# 0.9999999999941207
#
# 1.0000
# 0.9999999999941207
#
# 1.0000
# 0.9999999999941207
#
# 1.0000
# 0.9999999999941207
#
# 1.0000
# 0.9999999999941207
#
# 1.0000
# 0.9999999999941207
#
# 1.0000
# 0.9999999999941207
#
# 1.0000
# 0.9999999999941207
#
# 1.0000
# 0.9999999999941207
#
# 1.0000
# 0.9999999999941207
#
# 1.0000
# 0.9999999999941207
#
# 1.0000
# dataset_name:iris
# 0.9999999999873276
#
# 1.0000
# 0.9999999999873276
#
# 1.0000
# 0.9999999999873276
#
# 1.0000
# 0.9999999999873276
#
# 1.0000
# 0.9999999999873276
#
# 1.0000
# 0.9999999999873276
#
# 1.0000
# 0.9999999999873276
#
# 1.0000
# 0.9999999999873276
#
# 1.0000
# 0.999999999903766
#
# 1.0000
# 0.9999999999873276
#
# 1.0000
# 0.9999999999873276
#
# 1.0000
# 0.9999999999873276
#
# 1.0000
# dataset_name:iris
# 0.999999999988602
#
# 1.0000
# 0.999999999988602
#
# 1.0000
# 0.999999999988602
#
# 1.0000
# 0.999999999988602
#
# 1.0000
# 0.999999999988602
#
# 1.0000
# 0.999999999988602
#
# 1.0000
# 0.999999999988602
#
# 1.0000
# 0.999999999988602
#
# 1.0000
# 0.9999999999134672
#
# 1.0000
# 0.999999999988602
#
# 1.0000
# 0.999999999988602
#
# 1.0000
# 0.999999999988602
#
# 1.0000
# dataset_name:iris
# 0.9999999999897339
#
# 1.0000
# 0.9999999999897339
#
# 1.0000
# 0.9999999999897339
#
# 1.0000
# 0.9999999999897339
#
# 1.0000
# 0.9999999999897339
#
# 1.0000
# 0.9999999999897339
#
# 1.0000
# 0.9999999999897339
#
# 1.0000
# 0.9999999999897339
#
# 1.0000
# 0.9999999999220824
#
# 1.0000
# 0.9999999999897339
#
# 1.0000
# 0.9999999999897339
#
# 1.0000
# 0.9999999999897339
#
# 1.0000
# dataset_name:iris
# 0.9999999999907411
#
# 1.0000
# 0.9999999999907411
#
# 1.0000
# 0.9999999999907411
#
# 1.0000
# 0.9999999999907411
#
# 1.0000
# 0.9999999999907411
#
# 1.0000
# 0.9999999999907411
#
# 1.0000
# 0.9999999999907411
#
# 1.0000
# 0.9999999999907411
#
# 1.0000
# 0.9999999999297451
#
# 1.0000
# 0.9999999999907411
#
# 1.0000
# 0.9999999999907411
#
# 1.0000
# 0.9999999999907411
#
# 1.0000
# dataset_name:iris
# 0.9999999999916385
#
# 1.0000
# 0.9999999999916385
#
# 1.0000
# 0.9999999999916385
#
# 1.0000
# 0.9999999999916385
#
# 1.0000
# 0.9999999999916385
#
# 1.0000
# 0.9999999999916385
#
# 1.0000
# 0.9999999999916385
#
# 1.0000
# 0.9999999999916385
#
# 1.0000
# 0.9999999999365707
#
# 1.0000
# 0.9999999999916385
#
# 1.0000
# 0.9999999999916385
#
# 1.0000
# 0.9999999999916385
#
# 1.0000
# dataset_name:iris
# 0.9999999999924392
#
# 1.0000
# 0.9999999999924392
#
# 1.0000
# 0.9999999999924392
#
# 1.0000
# 0.9999999999924392
#
# 1.0000
# 0.9999999999924392
#
# 1.0000
# 0.9999999999924392
#
# 1.0000
# 0.9999999999924392
#
# 1.0000
# 0.9999999999924392
#
# 1.0000
# 0.9999999999426596
#
# 1.0000
# 0.9999999999924392
#
# 1.0000
# 0.9999999999924392
#
# 1.0000
# 0.9999999999924392
#
# 1.0000
# dataset_name:iris
# 0.9999999999931546
#
# 1.0000
# 0.9999999999931546
#
# 1.0000
# 0.9999999999931546
#
# 1.0000
# 0.9999999999931546
#
# 1.0000
# 0.9999999999931546
#
# 1.0000
# 0.9999999999931546
#
# 1.0000
# 0.9999999999931546
#
# 1.0000
# 0.9999999999931546
#
# 1.0000
# 0.9999999999480991
#
# 1.0000
# 0.9999999999931546
#
# 1.0000
# 0.9999999999931546
#
# 1.0000
# 0.9999999999931546
#
# 1.0000
# dataset_name:iris
# 0.9999999999937949
#
# 1.0000
# 0.9999999999937949
#
# 1.0000
# 0.9999999999937949
#
# 1.0000
# 0.9999999999937949
#
# 1.0000
# 0.9999999999937949
#
# 1.0000
# 0.9999999999937949
#
# 1.0000
# 0.9999999999937949
#
# 1.0000
# 0.9999999999937949
#
# 1.0000
# 0.9999999999529651
#
# 1.0000
# 0.9999999999937949
#
# 1.0000
# 0.9999999999937949
#
# 1.0000
# 0.9999999999937949
#
# 1.0000
# dataset_name:iris
# 0.9999999999943685
#
# 1.0000
# 0.9999999999943685
#
# 1.0000
# 0.9999999999943685
#
# 1.0000
# 0.9999999999943685
#
# 1.0000
# 0.9999999999943685
#
# 1.0000
# 0.9999999999943685
#
# 1.0000
# 0.9999999999943685
#
# 1.0000
# 0.9999999999943685
#
# 1.0000
# 0.9999999999573241
#
# 1.0000
# 0.9999999999943685
#
# 1.0000
# 0.9999999999943685
#
# 1.0000
# 0.9999999999943685
#
# 1.0000
# dataset_name:iris
# 0.9999999999948833
#
# 1.0000
# 0.9999999999948833
#
# 1.0000
# 0.9999999999948833
#
# 1.0000
# 0.9999999999948833
#
# 1.0000
# 0.9999999999948833
#
# 1.0000
# 0.9999999999948833
#
# 1.0000
# 0.9999999999948833
#
# 1.0000
# 0.9999999999948833
#
# 1.0000
# 0.999999999961234
#
# 1.0000
# 0.9999999999948833
#
# 1.0000
# 0.9999999999948833
#
# 1.0000
# 0.9999999999948833
#
# 1.0000
# dataset_name:iris
# 0.9999999999951206
#
# 1.0000
# 0.9999999999951206
#
# 1.0000
# 0.9999999999951206
#
# 1.0000
# 0.9999999999951206
#
# 1.0000
# 0.9999999999951206
#
# 1.0000
# 0.9999999999951206
#
# 1.0000
# 0.9999999999951206
#
# 1.0000
# 0.9999999999951206
#
# 1.0000
# 0.9999999999630367
#
# 1.0000
# 0.9999999999951206
#
# 1.0000
# 0.9999999999951206
#
# 1.0000
# 0.9999999999951206
#
# 1.0000
# dataset_name:letter
# 0.9999999999789972
#
# 1.0000
# 0.9999999999765726
#
# 1.0000
# 0.9999999999827758
#
# 1.0000
# 0.9999999999764696
#
# 1.0000
# 0.999999999984042
#
# 1.0000
# 0.9999999999792545
#
# 1.0000
# 0.9999999999826027
#
# 1.0000
# 0.9999999999839884
#
# 1.0000
# 0.999999999984042
#
# 1.0000
# 0.999999999971534
#
# 1.0000
# 0.9999999999880869
#
# 1.0000
# 0.9999999999601707
#
# 1.0000
# dataset_name:letter
# 0.9999999999891237
#
# 1.0000
# 0.9999999999879677
#
# 1.0000
# 0.9999999999910579
#
# 1.0000
# 0.9999999999881124
#
# 1.0000
# 0.9999999999915303
#
# 1.0000
# 0.999999999989246
#
# 1.0000
# 0.9999999999908206
#
# 1.0000
# 0.999999999991518
#
# 1.0000
# 0.9999999999915303
#
# 1.0000
# 0.9999999999851685
#
# 1.0000
# 0.9999999999937377
#
# 1.0000
# 0.9999999999805395
#
# 1.0000
# dataset_name:letter
# 0.9999999999940794
#
# 1.0000
# 0.9999999999934961
#
# 1.0000
# 0.9999999999951218
#
# 1.0000
# 0.9999999999936638
#
# 1.0000
# 0.9999999999952913
#
# 1.0000
# 0.9999999999941409
#
# 1.0000
# 0.9999999999949224
#
# 1.0000
# 0.9999999999952922
#
# 1.0000
# 0.9999999999952913
#
# 1.0000
# 0.9999999999918843
#
# 1.0000
# 0.999999999996547
#
# 1.0000
# 0.9999999999899166
#
# 1.0000
# dataset_name:letter
# 0.9999999999966359
#
# 1.0000
# 0.9999999999963268
#
# 1.0000
# 0.999999999997223
#
# 1.0000
# 0.9999999999964645
#
# 1.0000
# 0.9999999999972752
#
# 1.0000
# 0.9999999999966683
#
# 1.0000
# 0.9999999999970746
#
# 1.0000
# 0.9999999999972795
#
# 1.0000
# 0.9999999999972752
#
# 1.0000
# 0.9999999999953677
#
# 1.0000
# 0.9999999999980161
#
# 1.0000
# 0.9999999999945083
#
# 1.0000
# dataset_name:letter
# 0.9999999999980159
#
# 1.0000
# 0.9999999999978451
#
# 1.0000
# 0.9999999999983595
#
# 1.0000
# 0.9999999999979475
#
# 1.0000
# 0.9999999999983672
#
# 1.0000
# 0.9999999999980338
#
# 1.0000
# 0.9999999999982536
#
# 1.0000
# 0.9999999999983717
#
# 1.0000
# 0.9999999999983672
#
# 1.0000
# 0.9999999999972573
#
# 1.0000
# 0.9999999999988185
#
# 1.0000
# 0.9999999999968783
#
# 1.0000
# dataset_name:letter
# 0.999999999998791
#
# 1.0000
# 0.999999999998693
#
# 1.0000
# 0.9999999999989989
#
# 1.0000
# 0.9999999999987665
#
# 1.0000
# 0.9999999999989909
#
# 1.0000
# 0.9999999999988012
#
# 1.0000
# 0.9999999999989244
#
# 1.0000
# 0.9999999999989948
#
# 1.0000
# 0.9999999999989909
#
# 1.0000
# 0.9999999999983229
#
# 1.0000
# 0.9999999999992739
#
# 1.0000
# 0.9999999999981583
#
# 1.0000
# dataset_name:letter
# 0.9999999999992417
#
# 1.0000
# 0.9999999999991837
#
# 1.0000
# 0.9999999999993714
#
# 1.0000
# 0.9999999999992358
#
# 1.0000
# 0.9999999999993592
#
# 1.0000
# 0.9999999999992477
#
# 1.0000
# 0.999999999999319
#
# 1.0000
# 0.9999999999993623
#
# 1.0000
# 0.9999999999993592
#
# 1.0000
# 0.999999999998945
#
# 1.0000
# 0.9999999999995411
#
# 1.0000
# 0.9999999999988773
#
# 1.0000
# dataset_name:letter
# 0.9999999999995121
#
# 1.0000
# 0.9999999999994766
#
# 1.0000
# 0.999999999999595
#
# 1.0000
# 0.9999999999995136
#
# 1.0000
# 0.999999999999583
#
# 1.0000
# 0.9999999999995157
#
# 1.0000
# 0.999999999999558
#
# 1.0000
# 0.9999999999995854
#
# 1.0000
# 0.999999999999583
#
# 1.0000
# 0.9999999999993192
#
# 1.0000
# 0.9999999999997027
#
# 1.0000
# 0.9999999999992957
#
# 1.0000
# dataset_name:letter
# 0.9999999999996787
#
# 1.0000
# 0.9999999999996565
#
# 1.0000
# 0.9999999999997331
#
# 1.0000
# 0.9999999999996829
#
# 1.0000
# 0.9999999999997226
#
# 1.0000
# 0.999999999999681
#
# 1.0000
# 0.9999999999997067
#
# 1.0000
# 0.9999999999997244
#
# 1.0000
# 0.9999999999997226
#
# 1.0000
# 0.9999999999995506
#
# 1.0000
# 0.999999999999803
#
# 1.0000
# 0.9999999999995466
#
# 1.0000
# dataset_name:letter
# 0.999999999999784
#
# 1.0000
# 0.9999999999997697
#
# 1.0000
# 0.9999999999998204
#
# 1.0000
# 0.9999999999997887
#
# 1.0000
# 0.9999999999998118
#
# 1.0000
# 0.9999999999997854
#
# 1.0000
# 0.9999999999998015
#
# 1.0000
# 0.9999999999998133
#
# 1.0000
# 0.9999999999998118
#
# 1.0000
# 0.9999999999996972
#
# 1.0000
# 0.9999999999998669
#
# 1.0000
# 0.9999999999997014
#
# 1.0000
# dataset_name:letter
# 0.9999999999998217
#
# 1.0000
# 0.9999999999998102
#
# 1.0000
# 0.9999999999998516
#
# 1.0000
# 0.9999999999998263
#
# 1.0000
# 0.999999999999844
#
# 1.0000
# 0.9999999999998228
#
# 1.0000
# 0.9999999999998356
#
# 1.0000
# 0.9999999999998451
#
# 1.0000
# 0.999999999999844
#
# 1.0000
# 0.9999999999997498
#
# 1.0000
# 0.9999999999998898
#
# 1.0000
# 0.9999999999997558
#
# 1.0000
# dataset_name:mushroom
# 0.9999999999990747
#
# 1.0000
# 0.9999999999990747
#
# 1.0000
# 0.9999999999990747
#
# 1.0000
# 0.9999999999990747
#
# 1.0000
# 0.9999999999990747
#
# 1.0000
# 0.9999999999990747
#
# 1.0000
# 0.9999999999990747
#
# 1.0000
# 0.9999999999990747
#
# 1.0000
# 0.9999999999990747
#
# 1.0000
# 0.9999999999990747
#
# 1.0000
# 0.9999999999990747
#
# 1.0000
# 0.9999999999990747
#
# 1.0000
# dataset_name:mushroom
# 0.9999999999991975
#
# 1.0000
# 0.9999999999991975
#
# 1.0000
# 0.9999999999991975
#
# 1.0000
# 0.9999999999991975
#
# 1.0000
# 0.9999999999991975
#
# 1.0000
# 0.9999999999991975
#
# 1.0000
# 0.9999999999991975
#
# 1.0000
# 0.9999999999991975
#
# 1.0000
# 0.9999999999991975
#
# 1.0000
# 0.9999999999991975
#
# 1.0000
# 0.9999999999991975
#
# 1.0000
# 0.9999999999991975
#
# 1.0000
# dataset_name:mushroom
# 0.9999999999993023
#
# 1.0000
# 0.9999999999993023
#
# 1.0000
# 0.9999999999993023
#
# 1.0000
# 0.9999999999993023
#
# 1.0000
# 0.9999999999993023
#
# 1.0000
# 0.9999999999993023
#
# 1.0000
# 0.9999999999993023
#
# 1.0000
# 0.9999999999993023
#
# 1.0000
# 0.9999999999993023
#
# 1.0000
# 0.9999999999993023
#
# 1.0000
# 0.9999999999993023
#
# 1.0000
# 0.9999999999993023
#
# 1.0000
# dataset_name:mushroom
# 0.9999999999993919
#
# 1.0000
# 0.9999999999993919
#
# 1.0000
# 0.9999999999993919
#
# 1.0000
# 0.9999999999993919
#
# 1.0000
# 0.9999999999993919
#
# 1.0000
# 0.9999999999993919
#
# 1.0000
# 0.9999999999993919
#
# 1.0000
# 0.9999999999993919
#
# 1.0000
# 0.9999999999993919
#
# 1.0000
# 0.9999999999993919
#
# 1.0000
# 0.9999999999993919
#
# 1.0000
# 0.9999999999993919
#
# 1.0000
# dataset_name:mushroom
# 0.9999999999994688
#
# 1.0000
# 0.9999999999994688
#
# 1.0000
# 0.9999999999994688
#
# 1.0000
# 0.9999999999994688
#
# 1.0000
# 0.9999999999994688
#
# 1.0000
# 0.9999999999994688
#
# 1.0000
# 0.9999999999994688
#
# 1.0000
# 0.9999999999994688
#
# 1.0000
# 0.9999999999994688
#
# 1.0000
# 0.9999999999994688
#
# 1.0000
# 0.9999999999994688
#
# 1.0000
# 0.9999999999994688
#
# 1.0000
# dataset_name:mushroom
# 0.9999999999995349
#
# 1.0000
# 0.9999999999995349
#
# 1.0000
# 0.9999999999995349
#
# 1.0000
# 0.9999999999995349
#
# 1.0000
# 0.9999999999995349
#
# 1.0000
# 0.9999999999995349
#
# 1.0000
# 0.9999999999995349
#
# 1.0000
# 0.9999999999995349
#
# 1.0000
# 0.9999999999995349
#
# 1.0000
# 0.9999999999995349
#
# 1.0000
# 0.9999999999995349
#
# 1.0000
# 0.9999999999995349
#
# 1.0000
# dataset_name:mushroom
# 0.999999999999592
#
# 1.0000
# 0.999999999999592
#
# 1.0000
# 0.999999999999592
#
# 1.0000
# 0.999999999999592
#
# 1.0000
# 0.999999999999592
#
# 1.0000
# 0.999999999999592
#
# 1.0000
# 0.999999999999592
#
# 1.0000
# 0.999999999999592
#
# 1.0000
# 0.999999999999592
#
# 1.0000
# 0.999999999999592
#
# 1.0000
# 0.999999999999592
#
# 1.0000
# 0.999999999999592
#
# 1.0000
# dataset_name:mushroom
# 0.9999999999996413
#
# 1.0000
# 0.9999999999996413
#
# 1.0000
# 0.9999999999996413
#
# 1.0000
# 0.9999999999996413
#
# 1.0000
# 0.9999999999996413
#
# 1.0000
# 0.9999999999996413
#
# 1.0000
# 0.9999999999996413
#
# 1.0000
# 0.9999999999996413
#
# 1.0000
# 0.9999999999996413
#
# 1.0000
# 0.9999999999996413
#
# 1.0000
# 0.9999999999996413
#
# 1.0000
# 0.9999999999996413
#
# 1.0000
# dataset_name:mushroom
# 0.9999999999996839
#
# 1.0000
# 0.9999999999996839
#
# 1.0000
# 0.9999999999996839
#
# 1.0000
# 0.9999999999996839
#
# 1.0000
# 0.9999999999996839
#
# 1.0000
# 0.9999999999996839
#
# 1.0000
# 0.9999999999996839
#
# 1.0000
# 0.9999999999996839
#
# 1.0000
# 0.9999999999996839
#
# 1.0000
# 0.9999999999996839
#
# 1.0000
# 0.9999999999996839
#
# 1.0000
# 0.9999999999996839
#
# 1.0000
# dataset_name:mushroom
# 0.9999999999997209
#
# 1.0000
# 0.9999999999997209
#
# 1.0000
# 0.9999999999997209
#
# 1.0000
# 0.9999999999997209
#
# 1.0000
# 0.9999999999997209
#
# 1.0000
# 0.9999999999997209
#
# 1.0000
# 0.9999999999997209
#
# 1.0000
# 0.9999999999997209
#
# 1.0000
# 0.9999999999997209
#
# 1.0000
# 0.9999999999997209
#
# 1.0000
# 0.9999999999997209
#
# 1.0000
# 0.9999999999997209
#
# 1.0000
# dataset_name:mushroom
# 0.9999999999997377
#
# 1.0000
# 0.9999999999997377
#
# 1.0000
# 0.9999999999997377
#
# 1.0000
# 0.9999999999997377
#
# 1.0000
# 0.9999999999997377
#
# 1.0000
# 0.9999999999997377
#
# 1.0000
# 0.9999999999997377
#
# 1.0000
# 0.9999999999997377
#
# 1.0000
# 0.9999999999997377
#
# 1.0000
# 0.9999999999997377
#
# 1.0000
# 0.9999999999997377
#
# 1.0000
# 0.9999999999997377
#
# 1.0000
# dataset_name:segment
# 0.9999999998220278
#
# 1.0000
# 0.9999999998220278
#
# 1.0000
# 0.9999999982955311
#
# 1.0000
# 0.9999999981112835
#
# 1.0000
# 0.9999999997765674
#
# 1.0000
# 0.9999999998677134
#
# 1.0000
# 0.9999999994445808
#
# 1.0000
# 0.9999999998021307
#
# 1.0000
# 0.9999999989303262
#
# 1.0000
# 0.9999999992778552
#
# 1.0000
# 0.9999999999035863
#
# 1.0000
# 0.9999999992749564
#
# 1.0000
# dataset_name:segment
# 0.999999999858174
#
# 1.0000
# 0.999999999858174
#
# 1.0000
# 0.9999999986475776
#
# 1.0000
# 0.9999999985021061
#
# 1.0000
# 0.9999999998169606
#
# 1.0000
# 0.9999999998925639
#
# 1.0000
# 0.9999999995539454
#
# 1.0000
# 0.9999999998389403
#
# 1.0000
# 0.9999999991239865
#
# 1.0000
# 0.9999999994110571
#
# 1.0000
# 0.9999999999222187
#
# 1.0000
# 0.9999999994240878
#
# 1.0000
# dataset_name:segment
# 0.9999999998862721
#
# 1.0000
# 0.9999999998862721
#
# 1.0000
# 0.9999999989199718
#
# 1.0000
# 0.9999999988043458
#
# 1.0000
# 0.9999999998493264
#
# 1.0000
# 0.9999999999122868
#
# 1.0000
# 0.9999999996396876
#
# 1.0000
# 0.9999999998682271
#
# 1.0000
# 0.9999999992791144
#
# 1.0000
# 0.9999999995172667
#
# 1.0000
# 0.9999999999368985
#
# 1.0000
# 0.9999999995396089
#
# 1.0000
# dataset_name:segment
# 0.9999999999082636
#
# 1.0000
# 0.9999999999082636
#
# 1.0000
# 0.9999999991322258
#
# 1.0000
# 0.9999999990397394
#
# 1.0000
# 0.9999999998753976
#
# 1.0000
# 0.9999999999280307
#
# 1.0000
# 0.999999999707339
#
# 1.0000
# 0.9999999998916601
#
# 1.0000
# 0.9999999994040359
#
# 1.0000
# 0.9999999996024224
#
# 1.0000
# 0.9999999999485353
#
# 1.0000
# 0.9999999996297231
#
# 1.0000
# dataset_name:segment
# 0.9999999999255873
#
# 1.0000
# 0.9999999999255873
#
# 1.0000
# 0.9999999992987246
#
# 1.0000
# 0.9999999992243029
#
# 1.0000
# 0.9999999998965047
#
# 1.0000
# 0.9999999999406672
#
# 1.0000
# 0.9999999997610401
#
# 1.0000
# 0.9999999999105104
#
# 1.0000
# 0.9999999995051424
#
# 1.0000
# 0.9999999996710573
#
# 1.0000
# 0.9999999999578139
#
# 1.0000
# 0.9999999997004853
#
# 1.0000
# dataset_name:segment
# 0.999999999939318
#
# 1.0000
# 0.999999999939318
#
# 1.0000
# 0.9999999994301607
#
# 1.0000
# 0.9999999993699343
#
# 1.0000
# 0.9999999999136754
#
# 1.0000
# 0.9999999999508628
#
# 1.0000
# 0.999999999803913
#
# 1.0000
# 0.9999999999257518
#
# 1.0000
# 0.9999999995873692
#
# 1.0000
# 0.9999999997266551
#
# 1.0000
# 0.999999999965253
#
# 1.0000
# 0.9999999997564015
#
# 1.0000
# dataset_name:segment
# 0.9999999999502646
#
# 1.0000
# 0.9999999999502646
#
# 1.0000
# 0.9999999995345431
#
# 1.0000
# 0.9999999994855411
#
# 1.0000
# 0.9999999999277085
#
# 1.0000
# 0.9999999999591299
#
# 1.0000
# 0.9999999998383288
#
# 1.0000
# 0.9999999999381357
#
# 1.0000
# 0.9999999996545507
#
# 1.0000
# 0.9999999997719079
#
# 1.0000
# 0.9999999999712491
#
# 1.0000
# 0.9999999998008513
#
# 1.0000
# dataset_name:segment
# 0.9999999999590399
#
# 1.0000
# 0.9999999999590399
#
# 1.0000
# 0.9999999996179153
#
# 1.0000
# 0.9999999995778408
#
# 1.0000
# 0.9999999999392278
#
# 1.0000
# 0.9999999999658655
#
# 1.0000
# 0.9999999998660999
#
# 1.0000
# 0.9999999999482447
#
# 1.0000
# 0.9999999997096821
#
# 1.0000
# 0.9999999998089099
#
# 1.0000
# 0.9999999999761063
#
# 1.0000
# 0.9999999998363868
#
# 1.0000
# dataset_name:segment
# 0.999999999966112
#
# 1.0000
# 0.999999999966112
#
# 1.0000
# 0.9999999996848693
#
# 1.0000
# 0.9999999996519356
#
# 1.0000
# 0.9999999999487237
#
# 1.0000
# 0.9999999999713781
#
# 1.0000
# 0.9999999998886209
#
# 1.0000
# 0.9999999999565337
#
# 1.0000
# 0.9999999997551163
#
# 1.0000
# 0.9999999998392979
#
# 1.0000
# 0.9999999999800601
#
# 1.0000
# 0.9999999998649497
#
# 1.0000
# dataset_name:segment
# 0.9999999999718402
#
# 1.0000
# 0.9999999999718402
#
# 1.0000
# 0.9999999997389177
#
# 1.0000
# 0.9999999997117264
#
# 1.0000
# 0.9999999999565833
#
# 1.0000
# 0.9999999999759096
#
# 1.0000
# 0.9999999999069711
#
# 1.0000
# 0.9999999999633593
#
# 1.0000
# 0.9999999997927107
#
# 1.0000
# 0.9999999998643592
#
# 1.0000
# 0.999999999983293
#
# 1.0000
# 0.9999999998880267
#
# 1.0000
# dataset_name:segment
# 0.9999999999742898
#
# 1.0000
# 0.9999999999742898
#
# 1.0000
# 0.9999999997619732
#
# 1.0000
# 0.9999999997372242
#
# 1.0000
# 0.9999999999599981
#
# 1.0000
# 0.9999999999778684
#
# 1.0000
# 0.9999999999148524
#
# 1.0000
# 0.9999999999663137
#
# 1.0000
# 0.9999999998090411
#
# 1.0000
# 0.9999999998752188
#
# 1.0000
# 0.9999999999846851
#
# 1.0000
# 0.9999999998978768
#
# 1.0000
# dataset_name:sonar
# 0.4203687233012947
#
# 0.4204
# 0.4203687233012947
#
# 0.4204
# 0.00012618723005744487
#
# 0.0001
# 0.12642427175178092
#
# 0.1264
# 0.27746676351064586
#
# 0.2775
# 0.27746676351064586
#
# 0.2775
# 5.587708192922314e-06
#
# 0.0000
# 0.045880910427404054
#
# 0.0459
# 0.9149710111966198
#
# 0.9150
# 0.27746676351064586
#
# 0.2775
# 5.587708192922314e-06
#
# 0.0000
# 0.045880910427404054
#
# 0.0459
# dataset_name:sonar
# 0.773525532843421
#
# 0.7735
# 0.773525532843421
#
# 0.7735
# 0.0003838290116157192
#
# 0.0004
# 0.6050203970675111
#
# 0.6050
# 0.6582681583852513
#
# 0.6583
# 0.6582681583852513
#
# 0.6583
# 1.893083666892892e-05
#
# 0.0000
# 0.3779295260276656
#
# 0.3779
# 0.9842322933423556
#
# 0.9842
# 0.6582681583852513
#
# 0.6583
# 1.893083666892892e-05
#
# 0.0000
# 0.3779295260276656
#
# 0.3779
# dataset_name:sonar
# 0.943976176348854
#
# 0.9440
# 0.943976176348854
#
# 0.9440
# 0.001329504342238826
#
# 0.0013
# 0.943791975036412
#
# 0.9438
# 0.9090654338779454
#
# 0.9091
# 0.9090654338779454
#
# 0.9091
# 7.776384102975431e-05
#
# 0.0001
# 0.8804221560927542
#
# 0.8804
# 0.9969597120734585
#
# 0.9970
# 0.9090654338779454
#
# 0.9091
# 7.776384102975431e-05
#
# 0.0001
# 0.8804221560927542
#
# 0.8804
# dataset_name:sonar
# 0.9880687320855465
#
# 0.9881
# 0.9880687320855465
#
# 0.9881
# 0.005276762174420899
#
# 0.0053
# 0.9944953652888535
#
# 0.9945
# 0.9815615965485575
#
# 0.9816
# 0.9815615965485575
#
# 0.9816
# 0.0004088587562753876
#
# 0.0004
# 0.9895126984370103
#
# 0.9895
# 0.9993131699594383
#
# 0.9993
# 0.9815615965485575
#
# 0.9816
# 0.0004088587562753876
#
# 0.0004
# 0.9895126984370103
#
# 0.9895
# dataset_name:sonar
# 0.9972986317080648
#
# 0.9973
# 0.9972986317080648
#
# 0.9973
# 0.023325584074135722
#
# 0.0233
# 0.9993208838091633
#
# 0.9993
# 0.9961912982597512
#
# 0.9962
# 0.9961912982597512
#
# 0.9962
# 0.0029059358081755526
#
# 0.0029
# 0.9989431909463289
#
# 0.9989
# 0.999815745931718
#
# 0.9998
# 0.9961912982597512
#
# 0.9962
# 0.0029059358081755526
#
# 0.0029
# 0.9989431909463289
#
# 0.9989
# dataset_name:sonar
# 0.9992997725811882
#
# 0.9993
# 0.9992997725811882
#
# 0.9993
# 0.10221269689240087
#
# 0.1022
# 0.9998843704970366
#
# 0.9999
# 0.9990981769491393
#
# 0.9991
# 0.9990981769491393
#
# 0.9991
# 0.02730407718132899
#
# 0.0273
# 0.9998475022768171
#
# 0.9998
# 0.9999424028774827
#
# 0.9999
# 0.9990981769491393
#
# 0.9991
# 0.02730407718132899
#
# 0.0273
# 0.9998475022768171
#
# 0.9998
# dataset_name:sonar
# 0.9997905869094902
#
# 0.9998
# 0.9997905869094902
#
# 0.9998
# 0.3452438109856688
#
# 0.3452
# 0.9999741421947531
#
# 1.0000
# 0.9997502857310973
#
# 0.9998
# 0.9997502857310973
#
# 0.9998
# 0.231170554864771
#
# 0.2312
# 0.9999698118623842
#
# 1.0000
# 0.9999795219537893
#
# 1.0000
# 0.9997502857310973
#
# 0.9998
# 0.231170554864771
#
# 0.2312
# 0.9999698118623842
#
# 1.0000
# dataset_name:sonar
# 0.9999287528136614
#
# 0.9999
# 0.9999287528136614
#
# 0.9999
# 0.7032195600907107
#
# 0.7032
# 0.9999928465680223
#
# 1.0000
# 0.9999202170719326
#
# 0.9999
# 0.9999202170719326
#
# 0.9999
# 0.7497797599336706
#
# 0.7498
# 0.9999923672342323
#
# 1.0000
# 0.9999918975758086
#
# 1.0000
# 0.9999202170719326
#
# 0.9999
# 0.7497797599336706
#
# 0.7498
# 0.9999923672342323
#
# 1.0000
# dataset_name:sonar
# 0.9999729264779458
#
# 1.0000
# 0.9999729264779458
#
# 1.0000
# 0.9170555461680204
#
# 0.9171
# 0.9999976654197209
#
# 1.0000
# 0.9999711898627929
#
# 1.0000
# 0.9999711898627929
#
# 1.0000
# 0.9697210831977853
#
# 0.9697
# 0.9999976726811741
#
# 1.0000
# 0.9999964957664118
#
# 1.0000
# 0.9999711898627929
#
# 1.0000
# 0.9697210831977853
#
# 0.9697
# 0.9999976726811741
#
# 1.0000
# dataset_name:sonar
# 0.9999887046455164
#
# 1.0000
# 0.9999887046455164
#
# 1.0000
# 0.9813333387100421
#
# 0.9813
# 0.99999913215445
#
# 1.0000
# 0.999988470090007
#
# 1.0000
# 0.999988470090007
#
# 1.0000
# 0.9968030823842142
#
# 0.9968
# 0.9999991792693204
#
# 1.0000
# 0.9999983670033125
#
# 1.0000
# 0.999988470090007
#
# 1.0000
# 0.9968030823842142
#
# 0.9968
# 0.9999991792693204
#
# 1.0000
# dataset_name:sonar
# 0.9999924789254747
#
# 1.0000
# 0.9999924789254747
#
# 1.0000
# 0.9911675537921526
#
# 0.9912
# 0.9999994490123126
#
# 1.0000
# 0.9999924594638571
#
# 1.0000
# 0.9999924594638571
#
# 1.0000
# 0.9988559931172216
#
# 0.9989
# 0.9999994903005731
#
# 1.0000
# 0.9999988578038544
#
# 1.0000
# 0.9999924594638571
#
# 1.0000
# 0.9988559931172216
#
# 0.9989
# 0.9999994903005731
#
# 1.0000
# dataset_name:vowel
# 6.400847942282247e-05
#
# 0.0001
# 0.00015384867385826465
#
# 0.0002
# 0.00012795017035615246
#
# 0.0001
# 5.341753143155834e-08
#
# 0.0000
# 0.00036455858397408845
#
# 0.0004
# 0.0023347585924599038
#
# 0.0023
# 0.003961625327713496
#
# 0.0040
# 0.0018568454423260729
#
# 0.0019
# 2.8042979641090552e-05
#
# 0.0000
# 0.00015906084563096847
#
# 0.0002
# 5.876805481963237e-06
#
# 0.0000
# 7.94884424152927e-07
#
# 0.0000
# dataset_name:vowel
# 0.007738423974596252
#
# 0.0077
# 0.10044633590560625
#
# 0.1004
# 0.10026457814331345
#
# 0.1003
# 6.4498414159280725e-06
#
# 0.0000
# 0.06166375849191184
#
# 0.0617
# 0.38953896008725364
#
# 0.3895
# 0.9525196954827742
#
# 0.9525
# 0.5938915812900432
#
# 0.5939
# 0.04376440939220079
#
# 0.0438
# 0.0701998068794765
#
# 0.0702
# 0.00023600789541657462
#
# 0.0002
# 2.4965357174442372e-05
#
# 0.0000
# dataset_name:vowel
# 0.7608306689782895
#
# 0.7608
# 0.9942128453409727
#
# 0.9942
# 0.9954733854161871
#
# 0.9955
# 0.12865427101097757
#
# 0.1287
# 0.9496271965533434
#
# 0.9496
# 0.994574554592524
#
# 0.9946
# 0.9999580418605502
#
# 1.0000
# 0.9990445724184922
#
# 0.9990
# 0.9975040400774435
#
# 0.9975
# 0.9873151141941664
#
# 0.9873
# 0.058054359796752476
#
# 0.0581
# 0.00607389652716181
#
# 0.0061
# dataset_name:vowel
# 0.9990650910768212
#
# 0.9991
# 0.9999762787897203
#
# 1.0000
# 0.999982364244283
#
# 1.0000
# 0.9999444263237309
#
# 0.9999
# 0.9996889419535181
#
# 0.9997
# 0.9999371762498306
#
# 0.9999
# 0.9999993074691329
#
# 1.0000
# 0.9999892993215591
#
# 1.0000
# 0.9999943074825038
#
# 1.0000
# 0.9999500202325399
#
# 1.0000
# 0.9677737067132922
#
# 0.9678
# 0.900773255261277
#
# 0.9008
# dataset_name:vowel
# 0.9999841169485985
#
# 1.0000
# 0.9999992430299955
#
# 1.0000
# 0.9999994382758428
#
# 1.0000
# 0.9999998302054314
#
# 1.0000
# 0.9999907991912245
#
# 1.0000
# 0.9999970163144434
#
# 1.0000
# 0.9999999556730745
#
# 1.0000
# 0.9999994568159779
#
# 1.0000
# 0.9999998423590665
#
# 1.0000
# 0.9999985172213365
#
# 1.0000
# 0.9998467618619542
#
# 0.9998
# 0.9998434966008778
#
# 0.9998
# dataset_name:vowel
# 0.9999990360101749
#
# 1.0000
# 0.9999999339007085
#
# 1.0000
# 0.9999999508546544
#
# 1.0000
# 0.9999999942436502
#
# 1.0000
# 0.9999992550148271
#
# 1.0000
# 0.9999996842827181
#
# 1.0000
# 0.9999999943196488
#
# 1.0000
# 0.9999999394548266
#
# 1.0000
# 0.9999999869887055
#
# 1.0000
# 0.999999876080796
#
# 1.0000
# 0.9999956055790393
#
# 1.0000
# 0.9999973650462798
#
# 1.0000
# dataset_name:vowel
# 0.9999998819401198
#
# 1.0000
# 0.9999999898885431
#
# 1.0000
# 0.9999999924671542
#
# 1.0000
# 0.9999999994679585
#
# 1.0000
# 0.9999998921175276
#
# 1.0000
# 0.99999994604094
#
# 1.0000
# 0.9999999988957752
#
# 1.0000
# 0.9999999892595215
#
# 1.0000
# 0.9999999980667528
#
# 1.0000
# 0.9999999815654551
#
# 1.0000
# 0.9999996446896098
#
# 1.0000
# 0.9999998333900204
#
# 1.0000
# dataset_name:vowel
# 0.9999999778208402
#
# 1.0000
# 0.9999999977975599
#
# 1.0000
# 0.9999999983565464
#
# 1.0000
# 0.999999999915158
#
# 1.0000
# 0.9999999774195302
#
# 1.0000
# 0.9999999873742202
#
# 1.0000
# 0.999999999716849
#
# 1.0000
# 0.9999999974173142
#
# 1.0000
# 0.9999999995862181
#
# 1.0000
# 0.9999999960605803
#
# 1.0000
# 0.9999999483864428
#
# 1.0000
# 0.9999999789026028
#
# 1.0000
# dataset_name:vowel
# 0.9999999944581668
#
# 1.0000
# 0.9999999993887719
#
# 1.0000
# 0.9999999995433074
#
# 1.0000
# 0.9999999999809469
#
# 1.0000
# 0.999999993917804
#
# 1.0000
# 0.9999999963167647
#
# 1.0000
# 0.9999999999115705
#
# 1.0000
# 0.9999999992308346
#
# 1.0000
# 0.99999999988649
#
# 1.0000
# 0.9999999989217204
#
# 1.0000
# 0.999999989158655
#
# 1.0000
# 0.9999999959371221
#
# 1.0000
# dataset_name:vowel
# 0.9999999983037057
#
# 1.0000
# 0.999999999797696
#
# 1.0000
# 0.9999999998486848
#
# 1.0000
# 0.9999999999945887
#
# 1.0000
# 0.9999999980328613
#
# 1.0000
# 0.9999999987353604
#
# 1.0000
# 0.999999999967997
#
# 1.0000
# 0.9999999997316128
#
# 1.0000
# 0.9999999999627377
#
# 1.0000
# 0.9999999996468182
#
# 1.0000
# 0.9999999970705131
#
# 1.0000
# 0.999999998965732
#
# 1.0000
# dataset_name:vowel
# 0.9999999990042239
#
# 1.0000
# 0.9999999998773762
#
# 1.0000
# 0.999999999908241
#
# 1.0000
# 0.999999999996916
#
# 1.0000
# 0.9999999988191127
#
# 1.0000
# 0.9999999992219328
#
# 1.0000
# 0.9999999999798715
#
# 1.0000
# 0.9999999998337495
#
# 1.0000
# 0.9999999999774875
#
# 1.0000
# 0.9999999997868454
#
# 1.0000
# 0.9999999983641158
#
# 1.0000
# 0.9999999994357478
#
# 1.0000
# dataset_name:krkp
# 9.532579280191623e-12
#
# 0.0000
# 7.224032483321707e-11
#
# 0.0000
# 7.224032483321707e-11
#
# 0.0000
# 7.224032483321707e-11
#
# 0.0000
# 5.116229960510175e-13
#
# 0.0000
# 7.753856434174013e-12
#
# 0.0000
# 4.749427419518795e-11
#
# 0.0000
# 7.278328623720111e-11
#
# 0.0000
# 5.116229960510175e-13
#
# 0.0000
# 7.753856434174013e-12
#
# 0.0000
# 4.749427419518795e-11
#
# 0.0000
# 7.278328623720111e-11
#
# 0.0000
# dataset_name:krkp
# 2.407091076923374e-11
#
# 0.0000
# 1.8072821017511842e-10
#
# 0.0000
# 1.8072821017511842e-10
#
# 0.0000
# 1.8072821017511842e-10
#
# 0.0000
# 1.3161608693738014e-12
#
# 0.0000
# 2.0151488877802902e-11
#
# 0.0000
# 1.2110037507350954e-10
#
# 0.0000
# 1.9189120562809164e-10
#
# 0.0000
# 1.3161608693738014e-12
#
# 0.0000
# 2.0151488877802902e-11
#
# 0.0000
# 1.2110037507350954e-10
#
# 0.0000
# 1.9189120562809164e-10
#
# 0.0000
# dataset_name:krkp
# 6.860076838193967e-11
#
# 0.0000
# 5.088391930030411e-10
#
# 0.0000
# 5.088391930030411e-10
#
# 0.0000
# 5.088391930030411e-10
#
# 0.0000
# 3.84245277460619e-12
#
# 0.0000
# 5.95952954958968e-11
#
# 0.0000
# 3.4937081254109537e-10
#
# 0.0000
# 5.779009599053447e-10
#
# 0.0000
# 3.84245277460619e-12
#
# 0.0000
# 5.95952954958968e-11
#
# 0.0000
# 3.4937081254109537e-10
#
# 0.0000
# 5.779009599053447e-10
#
# 0.0000
# dataset_name:krkp
# 2.288041702989825e-10
#
# 0.0000
# 1.6692406346052735e-09
#
# 0.0000
# 1.6692406346052735e-09
#
# 0.0000
# 1.6692406346052735e-09
#
# 0.0000
# 1.3238108126566399e-11
#
# 0.0000
# 2.0880451438978968e-10
#
# 0.0000
# 1.1837941029550105e-09
#
# 0.0000
# 2.0733908594989772e-09
#
# 0.0000
# 1.3238108126566399e-11
#
# 0.0000
# 2.0880451438978968e-10
#
# 0.0000
# 1.1837941029550105e-09
#
# 0.0000
# 2.0733908594989772e-09
#
# 0.0000
# dataset_name:krkp
# 9.438947766317471e-10
#
# 0.0000
# 6.724019785409041e-09
#
# 0.0000
# 6.724019785409041e-09
#
# 0.0000
# 6.724019785409041e-09
#
# 0.0000
# 5.717921097972434e-11
#
# 0.0000
# 9.227069339043075e-10
#
# 0.0000
# 4.987806927398817e-09
#
# 0.0000
# 9.461554863049884e-09
#
# 0.0000
# 5.717921097972434e-11
#
# 0.0000
# 9.227069339043075e-10
#
# 0.0000
# 4.987806927398817e-09
#
# 0.0000
# 9.461554863049884e-09
#
# 0.0000
# dataset_name:krkp
# 5.272374427263425e-09
#
# 0.0000
# 3.619541744104282e-08
#
# 0.0000
# 3.619541744104282e-08
#
# 0.0000
# 3.619541744104282e-08
#
# 0.0000
# 3.425468037338005e-10
#
# 0.0000
# 5.710538263772368e-09
#
# 0.0000
# 2.869600329951322e-08
#
# 0.0000
# 6.129225405462578e-08
#
# 0.0000
# 3.425468037338005e-10
#
# 0.0000
# 5.710538263772368e-09
#
# 0.0000
# 2.869600329951322e-08
#
# 0.0000
# 6.129225405462578e-08
#
# 0.0000
# dataset_name:krkp
# 4.693356293407269e-08
#
# 0.0000
# 3.021424834770414e-07
#
# 0.0000
# 3.021424834770414e-07
#
# 0.0000
# 3.021424834770414e-07
#
# 0.0000
# 3.4349089408400858e-09
#
# 0.0000
# 6.016575086466652e-08
#
# 0.0000
# 2.668022830882072e-07
#
# 0.0000
# 6.915078086940759e-07
#
# 0.0000
# 3.4349089408400858e-09
#
# 0.0000
# 6.016575086466652e-08
#
# 0.0000
# 2.668022830882072e-07
#
# 0.0000
# 6.915078086940759e-07
#
# 0.0000
# dataset_name:krkp
# 9.334400088629927e-07
#
# 0.0000
# 5.251744365719624e-06
#
# 0.0000
# 5.251744365719624e-06
#
# 0.0000
# 5.251744365719624e-06
#
# 0.0000
# 8.721217776520875e-08
#
# 0.0000
# 1.6540269405445552e-06
#
# 0.0000
# 5.668018878357401e-06
#
# 0.0000
# 2.1070002678133577e-05
#
# 0.0000
# 8.721217776520875e-08
#
# 0.0000
# 1.6540269405445552e-06
#
# 0.0000
# 5.668018878357401e-06
#
# 0.0000
# 2.1070002678133577e-05
#
# 0.0000
# dataset_name:krkp
# 9.827299052980551e-05
#
# 0.0001
# 0.00037149613351050714
#
# 0.0004
# 0.00037149613351050714
#
# 0.0004
# 0.00037149613351050714
#
# 0.0004
# 1.9013370477341848e-05
#
# 0.0000
# 0.00038703265422413536
#
# 0.0004
# 0.0006315553995930399
#
# 0.0006
# 0.004887229695461565
#
# 0.0049
# 1.9013370477341848e-05
#
# 0.0000
# 0.00038703265422413536
#
# 0.0004
# 0.0006315553995930399
#
# 0.0006
# 0.004887229695461565
#
# 0.0049
# dataset_name:krkp
# 0.2527046344741095
#
# 0.2527
# 0.210284695182825
#
# 0.2103
# 0.210284695182825
#
# 0.2103
# 0.210284695182825
#
# 0.2103
# 0.6140549701268201
#
# 0.6141
# 0.78596113770548
#
# 0.7860
# 0.46450311351342083
#
# 0.4645
# 0.88479342119819
#
# 0.8848
# 0.6140549701268201
#
# 0.6141
# 0.78596113770548
#
# 0.7860
# 0.46450311351342083
#
# 0.4645
# 0.88479342119819
#
# 0.8848
# dataset_name:krkp
# 0.9697280872947808
#
# 0.9697
# 0.8957973886418693
#
# 0.8958
# 0.8957973886418693
#
# 0.8958
# 0.8957973886418693
#
# 0.8958
# 0.9990344244366464
#
# 0.9990
# 0.9976527101733638
#
# 0.9977
# 0.974359766249265
#
# 0.9744
# 0.9966699776530678
#
# 0.9967
# 0.9990344244366464
#
# 0.9990
# 0.9976527101733638
#
# 0.9977
# 0.974359766249265
#
# 0.9744
# 0.9966699776530678
#
# 0.9967
# dataset_name:xyguassian
# 1.0128853311641706e-10
#
# 0.0000
# 2.8385072070591377e-12
#
# 0.0000
# 2.8385072070591377e-12
#
# 0.0000
# 1.8653634580274815e-17
#
# 0.0000
# 1.1033693180358341e-15
#
# 0.0000
# 2.5875705321433536e-12
#
# 0.0000
# 2.702726931147481e-12
#
# 0.0000
# 9.715472317106272e-16
#
# 0.0000
# 1.1033693180358341e-15
#
# 0.0000
# 2.5875705321433536e-12
#
# 0.0000
# 2.702726931147481e-12
#
# 0.0000
# 9.715472317106272e-16
#
# 0.0000
# dataset_name:xyguassian
# 2.443211188918326e-10
#
# 0.0000
# 6.84541312523379e-12
#
# 0.0000
# 6.84541312523379e-12
#
# 0.0000
# 1.1102230246251565e-16
#
# 0.0000
# 2.660757705137282e-15
#
# 0.0000
# 6.112006764901854e-12
#
# 0.0000
# 6.36257713182431e-12
#
# 0.0000
# 2.263427570080146e-15
#
# 0.0000
# 2.660757705137282e-15
#
# 0.0000
# 6.112006764901854e-12
#
# 0.0000
# 6.36257713182431e-12
#
# 0.0000
# 2.263427570080146e-15
#
# 0.0000
# dataset_name:xyguassian
# 6.567481003472153e-10
#
# 0.0000
# 1.8404722190723533e-11
#
# 0.0000
# 1.8404722190723533e-11
#
# 0.0000
# 2.220446049250313e-16
#
# 0.0000
# 7.15476104863922e-15
#
# 0.0000
# 1.6008322602376483e-11
#
# 0.0000
# 1.6594836615979602e-11
#
# 0.0000
# 5.828072651050683e-15
#
# 0.0000
# 7.15476104863922e-15
#
# 0.0000
# 1.6008322602376483e-11
#
# 0.0000
# 1.6594836615979602e-11
#
# 0.0000
# 5.828072651050683e-15
#
# 0.0000
# dataset_name:xyguassian
# 2.0275525702828645e-09
#
# 0.0000
# 5.687628146233692e-11
#
# 0.0000
# 5.687628146233692e-11
#
# 0.0000
# 7.771561172376096e-16
#
# 0.0000
# 2.2124149071359893e-14
#
# 0.0000
# 4.7820648901362456e-11
#
# 0.0000
# 4.930489350130074e-11
#
# 0.0000
# 1.7037786962641977e-14
#
# 0.0000
# 2.2124149071359893e-14
#
# 0.0000
# 4.7820648901362456e-11
#
# 0.0000
# 4.930489350130074e-11
#
# 0.0000
# 1.7037786962641977e-14
#
# 0.0000
# dataset_name:xyguassian
# 7.517422129232898e-09
#
# 0.0000
# 2.114353137017133e-10
#
# 0.0000
# 2.114353137017133e-10
#
# 0.0000
# 2.9976021664879227e-15
#
# 0.0000
# 8.237849472378779e-14
#
# 0.0000
# 1.6982861248505977e-10
#
# 0.0000
# 1.7383083861233217e-10
#
# 0.0000
# 5.88229936962866e-14
#
# 0.0000
# 8.237849472378779e-14
#
# 0.0000
# 1.6982861248505977e-10
#
# 0.0000
# 1.7383083861233217e-10
#
# 0.0000
# 5.88229936962866e-14
#
# 0.0000
# dataset_name:xyguassian
# 3.589890440469645e-08
#
# 0.0000
# 1.016178807766721e-09
#
# 0.0000
# 1.016178807766721e-09
#
# 0.0000
# 1.4988010832439613e-14
#
# 0.0000
# 3.974553486364158e-13
#
# 0.0000
# 7.649531247014274e-10
#
# 0.0000
# 7.749847430460477e-10
#
# 0.0000
# 2.5497397669994824e-13
#
# 0.0000
# 3.974553486364158e-13
#
# 0.0000
# 7.649531247014274e-10
#
# 0.0000
# 7.749847430460477e-10
#
# 0.0000
# 2.5497397669994824e-13
#
# 0.0000
# dataset_name:xyguassian
# 2.4853738511687595e-07
#
# 0.0000
# 7.148478253782287e-09
#
# 0.0000
# 7.148478253782287e-09
#
# 0.0000
# 1.1046719095020308e-13
#
# 0.0000
# 2.823080457363079e-12
#
# 0.0000
# 4.873769841399674e-09
#
# 0.0000
# 4.861516744725236e-09
#
# 0.0000
# 1.5375796034076038e-12
#
# 0.0000
# 2.823080457363079e-12
#
# 0.0000
# 4.873769841399674e-09
#
# 0.0000
# 4.861516744725236e-09
#
# 0.0000
# 1.5375796034076038e-12
#
# 0.0000
# dataset_name:xyguassian
# 3.1125407711218855e-06
#
# 0.0000
# 9.368217268601597e-08
#
# 0.0000
# 9.368217268601597e-08
#
# 0.0000
# 1.5769607841775724e-12
#
# 0.0000
# 3.8037966528309485e-11
#
# 0.0000
# 5.394095850805963e-08
#
# 0.0000
# 5.2414271145551083e-08
#
# 0.0000
# 1.5641609574180448e-11
#
# 0.0000
# 3.8037966528309485e-11
#
# 0.0000
# 5.394095850805963e-08
#
# 0.0000
# 5.2414271145551083e-08
#
# 0.0000
# 1.5641609574180448e-11
#
# 0.0000
# dataset_name:xyguassian
# 0.00011258171867623012
#
# 0.0001
# 4.022931911484839e-06
#
# 0.0000
# 4.022931911484839e-06
#
# 0.0000
# 8.664535755542602e-11
#
# 0.0000
# 1.823437158495921e-09
#
# 0.0000
# 1.6387227459002496e-06
#
# 0.0000
# 1.510800009207891e-06
#
# 0.0000
# 4.139676248886e-10
#
# 0.0000
# 1.823437158495921e-09
#
# 0.0000
# 1.6387227459002496e-06
#
# 0.0000
# 1.510800009207891e-06
#
# 0.0000
# 4.139676248886e-10
#
# 0.0000
# dataset_name:xyguassian
# 0.027756513689922713
#
# 0.0278
# 0.0030835669938592547
#
# 0.0031
# 0.0030835669938592547
#
# 0.0031
# 3.572089832815095e-07
#
# 0.0000
# 3.862043583310141e-06
#
# 0.0000
# 0.0005054923435836514
#
# 0.0005
# 0.0004051536940561373
#
# 0.0004
# 1.125368485732206e-07
#
# 0.0000
# 3.862043583310141e-06
#
# 0.0000
# 0.0005054923435836514
#
# 0.0005
# 0.0004051536940561373
#
# 0.0004
# 1.125368485732206e-07
#
# 0.0000
# dataset_name:xyguassian
# 0.4258826759002625
#
# 0.4259
# 0.3176996507106784
#
# 0.3177
# 0.3176996507106784
#
# 0.3177
# 0.20913263580419694
#
# 0.2091
# 0.07253716001126315
#
# 0.0725
# 0.04884954952049539
#
# 0.0488
# 0.035393259802501076
#
# 0.0354
# 2.748532674333546e-05
#
# 0.0000
# 0.07253716001126315
#
# 0.0725
# 0.04884954952049539
#
# 0.0488
# 0.035393259802501076
#
# 0.0354
# 2.748532674333546e-05
#
# 0.0000
# dataset_name:yxguassian
# 0.9999999999991427
#
# 1.0000
# 0.9999999999991427
#
# 1.0000
# 0.9999999999991427
#
# 1.0000
# 0.9999999999991427
#
# 1.0000
# 0.9999999999991226
#
# 1.0000
# 0.9999999999991226
#
# 1.0000
# 0.9999999999991226
#
# 1.0000
# 0.9999999999991226
#
# 1.0000
# 0.9999999999991226
#
# 1.0000
# 0.9999999999991317
#
# 1.0000
# 0.9999999999991226
#
# 1.0000
# 0.9999999999991226
#
# 1.0000
# dataset_name:yxguassian
# 0.9999999999992475
#
# 1.0000
# 0.9999999999992475
#
# 1.0000
# 0.9999999999992475
#
# 1.0000
# 0.9999999999992475
#
# 1.0000
# 0.9999999999992298
#
# 1.0000
# 0.9999999999992298
#
# 1.0000
# 0.9999999999992298
#
# 1.0000
# 0.9999999999992298
#
# 1.0000
# 0.9999999999992298
#
# 1.0000
# 0.9999999999992378
#
# 1.0000
# 0.9999999999992298
#
# 1.0000
# 0.9999999999992298
#
# 1.0000
# dataset_name:yxguassian
# 0.9999999999993381
#
# 1.0000
# 0.9999999999993381
#
# 1.0000
# 0.9999999999993381
#
# 1.0000
# 0.9999999999993381
#
# 1.0000
# 0.9999999999993225
#
# 1.0000
# 0.9999999999993225
#
# 1.0000
# 0.9999999999993225
#
# 1.0000
# 0.9999999999993225
#
# 1.0000
# 0.9999999999993225
#
# 1.0000
# 0.9999999999993295
#
# 1.0000
# 0.9999999999993225
#
# 1.0000
# 0.9999999999993225
#
# 1.0000
# dataset_name:yxguassian
# 0.9999999999994166
#
# 1.0000
# 0.9999999999994166
#
# 1.0000
# 0.9999999999994166
#
# 1.0000
# 0.9999999999994166
#
# 1.0000
# 0.9999999999994028
#
# 1.0000
# 0.9999999999994028
#
# 1.0000
# 0.9999999999994028
#
# 1.0000
# 0.9999999999994028
#
# 1.0000
# 0.9999999999994028
#
# 1.0000
# 0.999999999999409
#
# 1.0000
# 0.9999999999994028
#
# 1.0000
# 0.9999999999994028
#
# 1.0000
# dataset_name:yxguassian
# 0.9999999999994847
#
# 1.0000
# 0.9999999999994847
#
# 1.0000
# 0.9999999999994847
#
# 1.0000
# 0.9999999999994847
#
# 1.0000
# 0.9999999999994725
#
# 1.0000
# 0.9999999999994725
#
# 1.0000
# 0.9999999999994725
#
# 1.0000
# 0.9999999999994725
#
# 1.0000
# 0.9999999999994725
#
# 1.0000
# 0.9999999999994781
#
# 1.0000
# 0.9999999999994725
#
# 1.0000
# 0.9999999999994725
#
# 1.0000
# dataset_name:yxguassian
# 0.999999999999544
#
# 1.0000
# 0.999999999999544
#
# 1.0000
# 0.999999999999544
#
# 1.0000
# 0.999999999999544
#
# 1.0000
# 0.9999999999995334
#
# 1.0000
# 0.9999999999995334
#
# 1.0000
# 0.9999999999995334
#
# 1.0000
# 0.9999999999995334
#
# 1.0000
# 0.9999999999995334
#
# 1.0000
# 0.9999999999995381
#
# 1.0000
# 0.9999999999995334
#
# 1.0000
# 0.9999999999995334
#
# 1.0000
# dataset_name:yxguassian
# 0.9999999999995958
#
# 1.0000
# 0.9999999999995958
#
# 1.0000
# 0.9999999999995958
#
# 1.0000
# 0.9999999999995958
#
# 1.0000
# 0.9999999999995863
#
# 1.0000
# 0.9999999999995863
#
# 1.0000
# 0.9999999999995863
#
# 1.0000
# 0.9999999999995863
#
# 1.0000
# 0.9999999999995863
#
# 1.0000
# 0.9999999999995905
#
# 1.0000
# 0.9999999999995863
#
# 1.0000
# 0.9999999999995863
#
# 1.0000
# dataset_name:yxguassian
# 0.9999999999996411
#
# 1.0000
# 0.9999999999996411
#
# 1.0000
# 0.9999999999996411
#
# 1.0000
# 0.9999999999996411
#
# 1.0000
# 0.9999999999996326
#
# 1.0000
# 0.9999999999996326
#
# 1.0000
# 0.9999999999996326
#
# 1.0000
# 0.9999999999996326
#
# 1.0000
# 0.9999999999996326
#
# 1.0000
# 0.9999999999996365
#
# 1.0000
# 0.9999999999996326
#
# 1.0000
# 0.9999999999996326
#
# 1.0000
# dataset_name:yxguassian
# 0.9999999999996807
#
# 1.0000
# 0.9999999999996807
#
# 1.0000
# 0.9999999999996807
#
# 1.0000
# 0.9999999999996807
#
# 1.0000
# 0.9999999999996733
#
# 1.0000
# 0.9999999999996733
#
# 1.0000
# 0.9999999999996733
#
# 1.0000
# 0.9999999999996733
#
# 1.0000
# 0.9999999999996733
#
# 1.0000
# 0.9999999999996766
#
# 1.0000
# 0.9999999999996733
#
# 1.0000
# 0.9999999999996733
#
# 1.0000
# dataset_name:yxguassian
# 0.9999999999997154
#
# 1.0000
# 0.9999999999997154
#
# 1.0000
# 0.9999999999997154
#
# 1.0000
# 0.9999999999997154
#
# 1.0000
# 0.9999999999997088
#
# 1.0000
# 0.9999999999997088
#
# 1.0000
# 0.9999999999997088
#
# 1.0000
# 0.9999999999997088
#
# 1.0000
# 0.9999999999997088
#
# 1.0000
# 0.9999999999997118
#
# 1.0000
# 0.9999999999997088
#
# 1.0000
# 0.9999999999997088
#
# 1.0000
# dataset_name:yxguassian
# 0.9999999999997312
#
# 1.0000
# 0.9999999999997312
#
# 1.0000
# 0.9999999999997312
#
# 1.0000
# 0.9999999999997312
#
# 1.0000
# 0.999999999999725
#
# 1.0000
# 0.999999999999725
#
# 1.0000
# 0.999999999999725
#
# 1.0000
# 0.999999999999725
#
# 1.0000
# 0.999999999999725
#
# 1.0000
# 0.9999999999997278
#
# 1.0000
# 0.999999999999725
#
# 1.0000
# 0.999999999999725
#
# 1.0000
# dataset_name:balancescale
# 0.999999901006073
#
# 1.0000
# 0.999999901006073
#
# 1.0000
# 0.999999901006073
#
# 1.0000
# 0.9999998433794661
#
# 1.0000
# 0.9999999927811726
#
# 1.0000
# 0.9999999927811726
#
# 1.0000
# 0.9999999995987345
#
# 1.0000
# 0.9999999853656204
#
# 1.0000
# 0.9999999927811726
#
# 1.0000
# 0.9999999927811726
#
# 1.0000
# 0.9999999995987345
#
# 1.0000
# 0.9999999898621356
#
# 1.0000
# dataset_name:balancescale
# 0.999999961280295
#
# 1.0000
# 0.999999961280295
#
# 1.0000
# 0.999999961280295
#
# 1.0000
# 0.9999999450375677
#
# 1.0000
# 0.9999999965110437
#
# 1.0000
# 0.9999999965110437
#
# 1.0000
# 0.9999999997617748
#
# 1.0000
# 0.9999999933541568
#
# 1.0000
# 0.9999999965110437
#
# 1.0000
# 0.9999999965110437
#
# 1.0000
# 0.9999999997617748
#
# 1.0000
# 0.9999999952261773
#
# 1.0000
# dataset_name:balancescale
# 0.999999983316492
#
# 1.0000
# 0.999999983316492
#
# 1.0000
# 0.999999983316492
#
# 1.0000
# 0.999999978278565
#
# 1.0000
# 0.9999999982095231
#
# 1.0000
# 0.9999999982095231
#
# 1.0000
# 0.9999999998540087
#
# 1.0000
# 0.9999999967629181
#
# 1.0000
# 0.9999999982095231
#
# 1.0000
# 0.9999999982095231
#
# 1.0000
# 0.9999999998540087
#
# 1.0000
# 0.9999999976032462
#
# 1.0000
# dataset_name:balancescale
# 0.9999999922206624
#
# 1.0000
# 0.9999999922206624
#
# 1.0000
# 0.9999999922206624
#
# 1.0000
# 0.999999990559905
#
# 1.0000
# 0.9999999990331647
#
# 1.0000
# 0.9999999990331647
#
# 1.0000
# 0.9999999999079813
#
# 1.0000
# 0.99999999832785
#
# 1.0000
# 0.9999999990331647
#
# 1.0000
# 0.9999999990331647
#
# 1.0000
# 0.9999999999079813
#
# 1.0000
# 0.9999999987297393
#
# 1.0000
# dataset_name:balancescale
# 0.9999999961266103
#
# 1.0000
# 0.9999999961266103
#
# 1.0000
# 0.9999999961266103
#
# 1.0000
# 0.9999999955662537
#
# 1.0000
# 0.9999999994545749
#
# 1.0000
# 0.9999999994545749
#
# 1.0000
# 0.9999999999405278
#
# 1.0000
# 0.9999999990919824
#
# 1.0000
# 0.9999999994545749
#
# 1.0000
# 0.9999999994545749
#
# 1.0000
# 0.9999999999405278
#
# 1.0000
# 0.9999999992948577
#
# 1.0000
# dataset_name:balancescale
# 0.9999999979616923
#
# 1.0000
# 0.9999999979616923
#
# 1.0000
# 0.9999999979616923
#
# 1.0000
# 0.9999999977787757
#
# 1.0000
# 0.9999999996803944
#
# 1.0000
# 0.9999999996803944
#
# 1.0000
# 0.9999999999606882
#
# 1.0000
# 0.9999999994852667
#
# 1.0000
# 0.9999999996803944
#
# 1.0000
# 0.9999999996803944
#
# 1.0000
# 0.9999999999606882
#
# 1.0000
# 0.9999999995925644
#
# 1.0000
# dataset_name:balancescale
# 0.9999999988754523
#
# 1.0000
# 0.9999999988754523
#
# 1.0000
# 0.9999999988754523
#
# 1.0000
# 0.9999999988249071
#
# 1.0000
# 0.9999999998063804
#
# 1.0000
# 0.9999999998063804
#
# 1.0000
# 0.9999999999734814
#
# 1.0000
# 0.9999999996971001
#
# 1.0000
# 0.9999999998063804
#
# 1.0000
# 0.9999999998063804
#
# 1.0000
# 0.9999999999734814
#
# 1.0000
# 0.9999999997561988
#
# 1.0000
# dataset_name:balancescale
# 0.999999999353718
#
# 1.0000
# 0.999999999353718
#
# 1.0000
# 0.999999999353718
#
# 1.0000
# 0.9999999993487003
#
# 1.0000
# 0.9999999998792038
#
# 1.0000
# 0.9999999998792038
#
# 1.0000
# 0.9999999999817791
#
# 1.0000
# 0.9999999998158161
#
# 1.0000
# 0.9999999998792038
#
# 1.0000
# 0.9999999998792038
#
# 1.0000
# 0.9999999999817791
#
# 1.0000
# 0.9999999998495491
#
# 1.0000
# dataset_name:balancescale
# 0.9999999996151081
#
# 1.0000
# 0.9999999996151081
#
# 1.0000
# 0.9999999996151081
#
# 1.0000
# 0.9999999996241804
#
# 1.0000
# 0.9999999999226399
#
# 1.0000
# 0.9999999999226399
#
# 1.0000
# 0.9999999999872687
#
# 1.0000
# 0.9999999998847103
#
# 1.0000
# 0.9999999999226399
#
# 1.0000
# 0.9999999999226399
#
# 1.0000
# 0.9999999999872687
#
# 1.0000
# 0.9999999999045825
#
# 1.0000
# dataset_name:balancescale
# 0.9999999997634792
#
# 1.0000
# 0.9999999997634792
#
# 1.0000
# 0.9999999997634792
#
# 1.0000
# 0.999999999775381
#
# 1.0000
# 0.9999999999492831
#
# 1.0000
# 0.9999999999492831
#
# 1.0000
# 0.9999999999909669
#
# 1.0000
# 0.9999999999259481
#
# 1.0000
# 0.9999999999492831
#
# 1.0000
# 0.9999999999492831
#
# 1.0000
# 0.9999999999909669
#
# 1.0000
# 0.9999999999379892
#
# 1.0000
# dataset_name:balancescale
# 0.9999999998126099
#
# 1.0000
# 0.9999999998126099
#
# 1.0000
# 0.9999999998126099
#
# 1.0000
# 0.9999999998242795
#
# 1.0000
# 0.9999999999586036
#
# 1.0000
# 0.9999999999586036
#
# 1.0000
# 0.9999999999923503
#
# 1.0000
# 0.9999999999401259
#
# 1.0000
# 0.9999999999586036
#
# 1.0000
# 0.9999999999586036
#
# 1.0000
# 0.9999999999923503
#
# 1.0000
# 0.9999999999495893
#
# 1.0000
# dataset_name:krkp
# 9.532579280191623e-12
#
# 0.0000
# 7.224032483321707e-11
#
# 0.0000
# 7.224032483321707e-11
#
# 0.0000
# 7.224032483321707e-11
#
# 0.0000
# 5.116229960510175e-13
#
# 0.0000
# 7.753856434174013e-12
#
# 0.0000
# 4.749427419518795e-11
#
# 0.0000
# 7.278328623720111e-11
#
# 0.0000
# 5.116229960510175e-13
#
# 0.0000
# 7.753856434174013e-12
#
# 0.0000
# 4.749427419518795e-11
#
# 0.0000
# 7.278328623720111e-11
#
# 0.0000
# dataset_name:krkp
# 2.407091076923374e-11
#
# 0.0000
# 1.8072821017511842e-10
#
# 0.0000
# 1.8072821017511842e-10
#
# 0.0000
# 1.8072821017511842e-10
#
# 0.0000
# 1.3161608693738014e-12
#
# 0.0000
# 2.0151488877802902e-11
#
# 0.0000
# 1.2110037507350954e-10
#
# 0.0000
# 1.9189120562809164e-10
#
# 0.0000
# 1.3161608693738014e-12
#
# 0.0000
# 2.0151488877802902e-11
#
# 0.0000
# 1.2110037507350954e-10
#
# 0.0000
# 1.9189120562809164e-10
#
# 0.0000
# dataset_name:krkp
# 6.860076838193967e-11
#
# 0.0000
# 5.088391930030411e-10
#
# 0.0000
# 5.088391930030411e-10
#
# 0.0000
# 5.088391930030411e-10
#
# 0.0000
# 3.84245277460619e-12
#
# 0.0000
# 5.95952954958968e-11
#
# 0.0000
# 3.4937081254109537e-10
#
# 0.0000
# 5.779009599053447e-10
#
# 0.0000
# 3.84245277460619e-12
#
# 0.0000
# 5.95952954958968e-11
#
# 0.0000
# 3.4937081254109537e-10
#
# 0.0000
# 5.779009599053447e-10
#
# 0.0000
# dataset_name:krkp
# 2.288041702989825e-10
#
# 0.0000
# 1.6692406346052735e-09
#
# 0.0000
# 1.6692406346052735e-09
#
# 0.0000
# 1.6692406346052735e-09
#
# 0.0000
# 1.3238108126566399e-11
#
# 0.0000
# 2.0880451438978968e-10
#
# 0.0000
# 1.1837941029550105e-09
#
# 0.0000
# 2.0733908594989772e-09
#
# 0.0000
# 1.3238108126566399e-11
#
# 0.0000
# 2.0880451438978968e-10
#
# 0.0000
# 1.1837941029550105e-09
#
# 0.0000
# 2.0733908594989772e-09
#
# 0.0000
# dataset_name:krkp
# 9.438947766317471e-10
#
# 0.0000
# 6.724019785409041e-09
#
# 0.0000
# 6.724019785409041e-09
#
# 0.0000
# 6.724019785409041e-09
#
# 0.0000
# 5.717921097972434e-11
#
# 0.0000
# 9.227069339043075e-10
#
# 0.0000
# 4.987806927398817e-09
#
# 0.0000
# 9.461554863049884e-09
#
# 0.0000
# 5.717921097972434e-11
#
# 0.0000
# 9.227069339043075e-10
#
# 0.0000
# 4.987806927398817e-09
#
# 0.0000
# 9.461554863049884e-09
#
# 0.0000
# dataset_name:krkp
# 5.272374427263425e-09
#
# 0.0000
# 3.619541744104282e-08
#
# 0.0000
# 3.619541744104282e-08
#
# 0.0000
# 3.619541744104282e-08
#
# 0.0000
# 3.425468037338005e-10
#
# 0.0000
# 5.710538263772368e-09
#
# 0.0000
# 2.869600329951322e-08
#
# 0.0000
# 6.129225405462578e-08
#
# 0.0000
# 3.425468037338005e-10
#
# 0.0000
# 5.710538263772368e-09
#
# 0.0000
# 2.869600329951322e-08
#
# 0.0000
# 6.129225405462578e-08
#
# 0.0000
# dataset_name:krkp
# 4.693356293407269e-08
#
# 0.0000
# 3.021424834770414e-07
#
# 0.0000
# 3.021424834770414e-07
#
# 0.0000
# 3.021424834770414e-07
#
# 0.0000
# 3.4349089408400858e-09
#
# 0.0000
# 6.016575086466652e-08
#
# 0.0000
# 2.668022830882072e-07
#
# 0.0000
# 6.915078086940759e-07
#
# 0.0000
# 3.4349089408400858e-09
#
# 0.0000
# 6.016575086466652e-08
#
# 0.0000
# 2.668022830882072e-07
#
# 0.0000
# 6.915078086940759e-07
#
# 0.0000
# dataset_name:krkp
# 9.334400088629927e-07
#
# 0.0000
# 5.251744365719624e-06
#
# 0.0000
# 5.251744365719624e-06
#
# 0.0000
# 5.251744365719624e-06
#
# 0.0000
# 8.721217776520875e-08
#
# 0.0000
# 1.6540269405445552e-06
#
# 0.0000
# 5.668018878357401e-06
#
# 0.0000
# 2.1070002678133577e-05
#
# 0.0000
# 8.721217776520875e-08
#
# 0.0000
# 1.6540269405445552e-06
#
# 0.0000
# 5.668018878357401e-06
#
# 0.0000
# 2.1070002678133577e-05
#
# 0.0000
# dataset_name:krkp
# 9.827299052980551e-05
#
# 0.0001
# 0.00037149613351050714
#
# 0.0004
# 0.00037149613351050714
#
# 0.0004
# 0.00037149613351050714
#
# 0.0004
# 1.9013370477341848e-05
#
# 0.0000
# 0.00038703265422413536
#
# 0.0004
# 0.0006315553995930399
#
# 0.0006
# 0.004887229695461565
#
# 0.0049
# 1.9013370477341848e-05
#
# 0.0000
# 0.00038703265422413536
#
# 0.0004
# 0.0006315553995930399
#
# 0.0006
# 0.004887229695461565
#
# 0.0049
# dataset_name:krkp
# 0.2527046344741095
#
# 0.2527
# 0.210284695182825
#
# 0.2103
# 0.210284695182825
#
# 0.2103
# 0.210284695182825
#
# 0.2103
# 0.6140549701268201
#
# 0.6141
# 0.78596113770548
#
# 0.7860
# 0.46450311351342083
#
# 0.4645
# 0.88479342119819
#
# 0.8848
# 0.6140549701268201
#
# 0.6141
# 0.78596113770548
#
# 0.7860
# 0.46450311351342083
#
# 0.4645
# 0.88479342119819
#
# 0.8848
# dataset_name:krkp
# 0.9697280872947808
#
# 0.9697
# 0.8957973886418693
#
# 0.8958
# 0.8957973886418693
#
# 0.8958
# 0.8957973886418693
#
# 0.8958
# 0.9990344244366464
#
# 0.9990
# 0.9976527101733638
#
# 0.9977
# 0.974359766249265
#
# 0.9744
# 0.9966699776530678
#
# 0.9967
# 0.9990344244366464
#
# 0.9990
# 0.9976527101733638
#
# 0.9977
# 0.974359766249265
#
# 0.9744
# 0.9966699776530678
#
# 0.9967
# dataset_name:waveform
# 0.9999999999723211
#
# 1.0000
# 0.9999999999723211
#
# 1.0000
# 0.9999999999981085
#
# 1.0000
# 0.9999999999981085
#
# 1.0000
# 0.9999999998214489
#
# 1.0000
# 0.9999999998070662
#
# 1.0000
# 0.9999999998214489
#
# 1.0000
# 0.9999999998214489
#
# 1.0000
# 0.9999999998214489
#
# 1.0000
# 0.9999999999483014
#
# 1.0000
# 0.9999999999489396
#
# 1.0000
# 0.9999999999489396
#
# 1.0000
# dataset_name:waveform
# 0.9999999999821466
#
# 1.0000
# 0.9999999999821466
#
# 1.0000
# 0.9999999999987118
#
# 1.0000
# 0.9999999999987118
#
# 1.0000
# 0.999999999893705
#
# 1.0000
# 0.9999999998929822
#
# 1.0000
# 0.999999999893705
#
# 1.0000
# 0.999999999893705
#
# 1.0000
# 0.999999999893705
#
# 1.0000
# 0.9999999999705163
#
# 1.0000
# 0.9999999999708632
#
# 1.0000
# 0.9999999999708632
#
# 1.0000
# dataset_name:waveform
# 0.9999999999882196
#
# 1.0000
# 0.9999999999882196
#
# 1.0000
# 0.999999999999107
#
# 1.0000
# 0.999999999999107
#
# 1.0000
# 0.999999999934699
#
# 1.0000
# 0.9999999999381991
#
# 1.0000
# 0.999999999934699
#
# 1.0000
# 0.999999999934699
#
# 1.0000
# 0.999999999934699
#
# 1.0000
# 0.9999999999825563
#
# 1.0000
# 0.9999999999827528
#
# 1.0000
# 0.9999999999827528
#
# 1.0000
# dataset_name:waveform
# 0.9999999999920659
#
# 1.0000
# 0.9999999999920659
#
# 1.0000
# 0.9999999999993711
#
# 1.0000
# 0.9999999999993711
#
# 1.0000
# 0.9999999999587496
#
# 1.0000
# 0.9999999999630347
#
# 1.0000
# 0.9999999999587496
#
# 1.0000
# 0.9999999999587496
#
# 1.0000
# 0.9999999999587496
#
# 1.0000
# 0.9999999999893416
#
# 1.0000
# 0.9999999999894569
#
# 1.0000
# 0.9999999999894569
#
# 1.0000
# dataset_name:waveform
# 0.9999999999945562
#
# 1.0000
# 0.9999999999945562
#
# 1.0000
# 0.9999999999995505
#
# 1.0000
# 0.9999999999995505
#
# 1.0000
# 0.9999999999732864
#
# 1.0000
# 0.9999999999771954
#
# 1.0000
# 0.9999999999732864
#
# 1.0000
# 0.9999999999732864
#
# 1.0000
# 0.9999999999732864
#
# 1.0000
# 0.9999999999932992
#
# 1.0000
# 0.999999999993369
#
# 1.0000
# 0.999999999993369
#
# 1.0000
# dataset_name:waveform
# 0.9999999999962011
#
# 1.0000
# 0.9999999999962011
#
# 1.0000
# 0.9999999999996743
#
# 1.0000
# 0.9999999999996743
#
# 1.0000
# 0.9999999999823099
#
# 1.0000
# 0.9999999999855401
#
# 1.0000
# 0.9999999999823099
#
# 1.0000
# 0.9999999999823099
#
# 1.0000
# 0.9999999999823099
#
# 1.0000
# 0.9999999999956789
#
# 1.0000
# 0.9999999999957223
#
# 1.0000
# 0.9999999999957223
#
# 1.0000
# dataset_name:waveform
# 0.9999999999973078
#
# 1.0000
# 0.9999999999973078
#
# 1.0000
# 0.9999999999997611
#
# 1.0000
# 0.9999999999997611
#
# 1.0000
# 0.9999999999880471
#
# 1.0000
# 0.9999999999906041
#
# 1.0000
# 0.9999999999880471
#
# 1.0000
# 0.9999999999880471
#
# 1.0000
# 0.9999999999880471
#
# 1.0000
# 0.9999999999971494
#
# 1.0000
# 0.9999999999971771
#
# 1.0000
# 0.9999999999971771
#
# 1.0000
# dataset_name:waveform
# 0.9999999999980648
#
# 1.0000
# 0.9999999999980648
#
# 1.0000
# 0.9999999999998227
#
# 1.0000
# 0.9999999999998227
#
# 1.0000
# 0.9999999999917747
#
# 1.0000
# 0.9999999999937588
#
# 1.0000
# 0.9999999999917747
#
# 1.0000
# 0.9999999999917747
#
# 1.0000
# 0.9999999999917747
#
# 1.0000
# 0.9999999999980803
#
# 1.0000
# 0.9999999999980985
#
# 1.0000
# 0.9999999999980985
#
# 1.0000
# dataset_name:waveform
# 0.9999999999985907
#
# 1.0000
# 0.9999999999985907
#
# 1.0000
# 0.999999999999867
#
# 1.0000
# 0.999999999999867
#
# 1.0000
# 0.9999999999942448
#
# 1.0000
# 0.9999999999957712
#
# 1.0000
# 0.9999999999942448
#
# 1.0000
# 0.9999999999942448
#
# 1.0000
# 0.9999999999942448
#
# 1.0000
# 0.999999999998683
#
# 1.0000
# 0.9999999999986952
#
# 1.0000
# 0.9999999999986952
#
# 1.0000
# dataset_name:waveform
# 0.9999999999989612
#
# 1.0000
# 0.9999999999989612
#
# 1.0000
# 0.9999999999998993
#
# 1.0000
# 0.9999999999998993
#
# 1.0000
# 0.9999999999959114
#
# 1.0000
# 0.9999999999970826
#
# 1.0000
# 0.9999999999959114
#
# 1.0000
# 0.9999999999959114
#
# 1.0000
# 0.9999999999959114
#
# 1.0000
# 0.9999999999990812
#
# 1.0000
# 0.9999999999990893
#
# 1.0000
# 0.9999999999990893
#
# 1.0000
# dataset_name:waveform
# 0.9999999999991043
#
# 1.0000
# 0.9999999999991043
#
# 1.0000
# 0.999999999999912
#
# 1.0000
# 0.999999999999912
#
# 1.0000
# 0.9999999999965354
#
# 1.0000
# 0.9999999999975616
#
# 1.0000
# 0.9999999999965354
#
# 1.0000
# 0.9999999999965354
#
# 1.0000
# 0.9999999999965354
#
# 1.0000
# 0.999999999999228
#
# 1.0000
# 0.9999999999992347
#
# 1.0000
# 0.9999999999992347
#
# 1.0000
# dataset_name:splice
# 8.442517140426564e-11
#
# 0.0000
# 2.2552592182407647e-10
#
# 0.0000
# 7.497587708370203e-11
#
# 0.0000
# 2.3328876316280074e-10
#
# 0.0000
# 2.7655070908134014e-09
#
# 0.0000
# 5.532837661593428e-10
#
# 0.0000
# 1.3493791159241964e-07
#
# 0.0000
# 1.1234893955285646e-09
#
# 0.0000
# 1.7217197805684595e-08
#
# 0.0000
# 3.7142300594606285e-10
#
# 0.0000
# 4.782193863418927e-10
#
# 0.0000
# 7.92032658782131e-09
#
# 0.0000
# dataset_name:splice
# 2.7410520272611735e-10
#
# 0.0000
# 7.298035139724418e-10
#
# 0.0000
# 2.408453837980999e-10
#
# 0.0000
# 7.59884014807032e-10
#
# 0.0000
# 2.1410899064910798e-08
#
# 0.0000
# 2.1890463166253535e-09
#
# 0.0000
# 2.6704612552331817e-06
#
# 0.0000
# 5.434962939978961e-09
#
# 0.0000
# 4.843258622691516e-07
#
# 0.0000
# 2.0449786227573947e-09
#
# 0.0000
# 4.528671841901705e-09
#
# 0.0000
# 3.841756028126641e-08
#
# 0.0000
# dataset_name:splice
# 1.089486899104114e-09
#
# 0.0000
# 2.886428308196295e-09
#
# 0.0000
# 9.434389106539362e-10
#
# 0.0000
# 3.0324855690551005e-09
#
# 0.0000
# 3.310561644532523e-07
#
# 0.0000
# 1.1492877914631554e-08
#
# 0.0000
# 0.0002639363578044252
#
# 0.0003
# 3.8535146485831994e-08
#
# 0.0000
# 0.0001308485513823075
#
# 0.0001
# 1.7815030000639772e-08
#
# 0.0000
# 1.0267265229059329e-07
#
# 0.0000
# 2.723795489717456e-07
#
# 0.0000
# dataset_name:splice
# 5.7618523434179e-09
#
# 0.0000
# 1.514254890040482e-08
#
# 0.0000
# 4.885298962214234e-09
#
# 0.0000
# 1.611724051773267e-08
#
# 0.0000
# 1.9983960337728625e-05
#
# 0.0000
# 9.248929915826218e-08
#
# 0.0000
# 0.3138279949703021
#
# 0.3138
# 5.085998956506325e-07
#
# 0.0000
# 0.8097596951782919
#
# 0.8098
# 3.42292774654518e-07
#
# 0.0000
# 1.6336029151707548e-05
#
# 0.0000
# 3.5507396400623793e-06
#
# 0.0000
# dataset_name:splice
# 4.697597658027287e-08
#
# 0.0000
# 1.2163255378728632e-07
#
# 0.0000
# 3.85313835569855e-08
#
# 0.0000
# 1.3214184711294948e-07
#
# 0.0000
# 0.028968807517624005
#
# 0.0290
# 1.5201020341270975e-06
#
# 0.0000
# 0.9990779102662783
#
# 0.9991
# 2.1519213260649586e-05
#
# 0.0000
# 0.9999790925221403
#
# 1.0000
# 3.4383723550405814e-05
#
# 0.0000
# 0.3534134635109806
#
# 0.3534
# 0.00013868415222942842
#
# 0.0001
# dataset_name:splice
# 7.941368349144226e-07
#
# 0.0000
# 1.98824682285376e-06
#
# 0.0000
# 6.141382091010048e-07
#
# 0.0000
# 2.2401219150344543e-06
#
# 0.0000
# 0.9968711861638456
#
# 0.9969
# 0.00010049727050705359
#
# 0.0001
# 0.999994375930607
#
# 1.0000
# 0.011517564782320059
#
# 0.0115
# 0.9999998233151992
#
# 1.0000
# 0.1537703937694984
#
# 0.1538
# 0.9999668967207983
#
# 1.0000
# 0.038056086424626795
#
# 0.0381
# dataset_name:splice
# 5.728578174189191e-05
#
# 0.0001
# 0.00012849964986110958
#
# 0.0001
# 3.905499793260712e-05
#
# 0.0000
# 0.00015628461132605095
#
# 0.0002
# 0.9999940814124447
#
# 1.0000
# 0.09761523589068466
#
# 0.0976
# 0.9999997741652344
#
# 1.0000
# 0.9786470389428337
#
# 0.9786
# 0.9999999913196032
#
# 1.0000
# 0.9996479859864473
#
# 0.9996
# 0.9999998495512601
#
# 1.0000
# 0.9636764852644614
#
# 0.9637
# dataset_name:splice
# 0.08791360782185628
#
# 0.0879
# 0.10616813157397866
#
# 0.1062
# 0.05141567513215183
#
# 0.0514
# 0.13734061233013353
#
# 0.1373
# 0.9999998468443534
#
# 1.0000
# 0.9965612270367723
#
# 0.9966
# 0.9999999776240704
#
# 1.0000
# 0.9999690199628374
#
# 1.0000
# 0.9999999990317823
#
# 1.0000
# 0.9999987386610644
#
# 1.0000
# 0.9999999941344285
#
# 1.0000
# 0.9998657999235815
#
# 0.9999
# dataset_name:splice
# 0.9980601573339548
#
# 0.9981
# 0.9959485061893739
#
# 0.9959
# 0.9969409988097212
#
# 0.9969
# 0.9969143798753789
#
# 0.9969
# 0.9999999877600515
#
# 1.0000
# 0.999987443381462
#
# 1.0000
# 0.9999999962986355
#
# 1.0000
# 0.9999993571717574
#
# 1.0000
# 0.9999999998271206
#
# 1.0000
# 0.9999999566507808
#
# 1.0000
# 0.9999999994187773
#
# 1.0000
# 0.9999965262312029
#
# 1.0000
# dataset_name:splice
# 0.9999938357605851
#
# 1.0000
# 0.9999839960897172
#
# 1.0000
# 0.9999922699187613
#
# 1.0000
# 0.9999864352486313
#
# 1.0000
# 0.9999999982148884
#
# 1.0000
# 0.9999996024623805
#
# 1.0000
# 0.9999999991500407
#
# 1.0000
# 0.9999999542932829
#
# 1.0000
# 0.9999999999581368
#
# 1.0000
# 0.999999995994602
#
# 1.0000
# 0.9999999999033896
#
# 1.0000
# 0.9999997319857993
#
# 1.0000
# dataset_name:splice
# 0.9999990895883127
#
# 1.0000
# 0.999997580566528
#
# 1.0000
# 0.9999989215727154
#
# 1.0000
# 0.9999978857637022
#
# 1.0000
# 0.9999999992092067
#
# 1.0000
# 0.9999998925122586
#
# 1.0000
# 0.9999999995544667
#
# 1.0000
# 0.9999999841452175
#
# 1.0000
# 0.9999999999775936
#
# 1.0000
# 0.9999999984836278
#
# 1.0000
# 0.9999999999551088
#
# 1.0000
# 0.9999999048538751
#
# 1.0000

# %%
#  ,
dataset_names=['breastcancer', 'wdbc', 'iris', 'letter', 'mushroom', 'segment',
       'sonar', 'vowel', 'xyguassian', 'yxguassian', 'balancescale',
       'krkp', 'waveform', 'splice', 'g241n','g241c', 'digit1', 'usps', 'coil',
       'coil2', 'bci', 'secstr', 'cifar10','splice2balance','xyguassian100','xyguassian200','xyguassian500','xyguassian5000','xyguassian1000','yxguassian100','yxguassian200','yxguassian500','yxguassian1000','yxguassian5000']

#dataset_names=['krkp']
#dataset_names = corr_table_total['dataset'].unique()
noise_types = ['sym','instance','pair']
#noise_types = ['sym']
initial_noise_list = [0, 0.1,0.2,0.3]

corr_table_total2 = corr_table_total[corr_table_total['dataset'].isin(dataset_names) & corr_table_total['noise_type'].isin(noise_types) & corr_table_total['initial_noise'].isin(initial_noise_list)]
corr_table_total2['combine']=corr_table_total2['dataset']+'_'+corr_table_total2['noise_type']+'_'+corr_table_total2['initial_noise'].astype(str)


def check_string(string, word_list):
    return any(word in string for word in word_list)

#isCausal = ['krkp','xyguassian','secstr','splice']

isCausal = ['xyguassian']

plt.figure(figsize=(10, 10))

num_causal_success=0
num_anticausal_success=0

for group in corr_table_total2['combine'].unique():
    group_data = corr_table_total2[corr_table_total2['combine']==group].sort_values(by='threshold')
    # extract the first part of the combine separated bu '_'
    dataset_name_extract=(group_data['combine'].to_list()[0].split('_')[0])
    
    if (check_string(dataset_name_extract, isCausal)):
        #print(dataset_name_extract+" is causal")
        plt.plot(group_data['threshold'], group_data['p_value'], linestyle='--')
        plt.scatter(group_data['threshold'], group_data['p_value'], label=group, marker='*')
    else:
        
        print(dataset_name_extract+" is not causal")
        #plt.plot(group_data['threshold'], group_data['p_value'], linestyle='solid')
        #plt.scatter(group_data['threshold'], group_data['p_value'], label=group, marker='o')
# 设置坐标轴标签


plt.xlabel('Threshold')
plt.ylabel('P-value')
plt.ylim(-0.1,2)
plt.axhline(y=0.025, color='r', linestyle='--')
#plt.axvline(x=0.05, c='b', linestyle='--')

# 显示图例
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
#plt.legend(['Causal','Anti-causal','P-value=0.025'])
# save plot as pdf 
#plt.savefig('./results/pdf/pvalue_threshold.pdf')
# reverse y axis


# 显示图像
plt.show()
# Out:
# breastcancer is not causal
# breastcancer is not causal
# breastcancer is not causal
# breastcancer is not causal
# breastcancer is not causal
# breastcancer is not causal
# breastcancer is not causal
# breastcancer is not causal
# breastcancer is not causal
# breastcancer is not causal
# breastcancer is not causal
# breastcancer is not causal
# wdbc is not causal
# wdbc is not causal
# wdbc is not causal
# wdbc is not causal
# wdbc is not causal
# wdbc is not causal
# wdbc is not causal
# wdbc is not causal
# wdbc is not causal
# wdbc is not causal
# wdbc is not causal
# wdbc is not causal
# iris is not causal
# iris is not causal
# iris is not causal
# iris is not causal
# iris is not causal
# iris is not causal
# iris is not causal
# iris is not causal
# iris is not causal
# iris is not causal
# iris is not causal
# iris is not causal
# letter is not causal
# letter is not causal
# letter is not causal
# letter is not causal
# letter is not causal
# letter is not causal
# letter is not causal
# letter is not causal
# letter is not causal
# letter is not causal
# letter is not causal
# letter is not causal
# mushroom is not causal
# mushroom is not causal
# mushroom is not causal
# mushroom is not causal
# mushroom is not causal
# mushroom is not causal
# mushroom is not causal
# mushroom is not causal
# mushroom is not causal
# mushroom is not causal
# mushroom is not causal
# mushroom is not causal
# segment is not causal
# segment is not causal
# segment is not causal
# segment is not causal
# segment is not causal
# segment is not causal
# segment is not causal
# segment is not causal
# segment is not causal
# segment is not causal
# segment is not causal
# segment is not causal
# sonar is not causal
# sonar is not causal
# sonar is not causal
# sonar is not causal
# sonar is not causal
# sonar is not causal
# sonar is not causal
# sonar is not causal
# sonar is not causal
# sonar is not causal
# sonar is not causal
# sonar is not causal
# vowel is not causal
# vowel is not causal
# vowel is not causal
# vowel is not causal
# vowel is not causal
# vowel is not causal
# vowel is not causal
# vowel is not causal
# vowel is not causal
# vowel is not causal
# vowel is not causal
# vowel is not causal
# krkp is not causal
# krkp is not causal
# krkp is not causal
# krkp is not causal
# krkp is not causal
# krkp is not causal
# krkp is not causal
# krkp is not causal
# krkp is not causal
# krkp is not causal
# krkp is not causal
# krkp is not causal
# yxguassian is not causal
# yxguassian is not causal
# yxguassian is not causal
# yxguassian is not causal
# yxguassian is not causal
# yxguassian is not causal
# yxguassian is not causal
# yxguassian is not causal
# yxguassian is not causal
# yxguassian is not causal
# yxguassian is not causal
# yxguassian is not causal
# balancescale is not causal
# balancescale is not causal
# balancescale is not causal
# balancescale is not causal
# balancescale is not causal
# balancescale is not causal
# balancescale is not causal
# balancescale is not causal
# balancescale is not causal
# balancescale is not causal
# balancescale is not causal
# balancescale is not causal
# waveform is not causal
# waveform is not causal
# waveform is not causal
# waveform is not causal
# waveform is not causal
# waveform is not causal
# waveform is not causal
# waveform is not causal
# waveform is not causal
# waveform is not causal
# waveform is not causal
# waveform is not causal
# splice is not causal
# splice is not causal
# splice is not causal
# splice is not causal
# splice is not causal
# splice is not causal
# splice is not causal
# splice is not causal
# splice is not causal
# splice is not causal
# splice is not causal
# splice is not causal

# %%
# select only dataset = splice
corr_table_total2.to_csv('./results/csv/pvalue_xyyx200-20000.csv')

# %%
#corr_table_total2.to_csv('./results/csv/corr_table_allDataCombined.csv', index=False)

#drop duplicate based on combined column of corr_table_total2
corr_table_total3=corr_table_total2.drop_duplicates(subset=['combine'], keep='first')

# print row and column of corr_table_total2 and corr_table_total3
corr_table_total3.shape, corr_table_total2.shape, len(corr_table_total2['dataset'].unique())


corr_table_total3.to_csv('./results/csv/corr_table_instance_noise.csv')

# %%
corr_table_total2['dataset'].unique()
# Out:
# array(['xyguassian200', 'xyguassian500', 'xyguassian5000', 'xyguassian'],
#       dtype=object)

# %%
import seaborn as sns
# read
df = pd.read_csv('./results/csv/pvalue_xyyx200-20000.csv')
#df2 = pd.read_csv('./results/csv/corr_table_allDataCombined_4digit.csv')
#df=pd.concat([df,df2])

dataset_names = ['xyguassian','xyguassian200','xyguassian1000','xyguassian5000','yxguassian','yxguassian200','yxguassian1000','yxguassian5000']
#,'secstr','splice']
#dataset_names = ['yxguassian200','yxguassian1000','yxguassian5000']
# select only initial noise = 0.0 and noise type is sym
df = df[ (df['dataset'].isin(dataset_names)) & ((df['initial_noise']!=0.9) ) & (df['noise_type']=='sym')]
df['dataset'].unique()
# Out:
# array(['xyguassian200', 'yxguassian200', 'xyguassian1000',
#        'yxguassian1000', 'xyguassian5000', 'yxguassian5000', 'xyguassian',
#        'yxguassian'], dtype=object)

# %%
# rename xyguassian as xyguassian20000
df['dataset'] = df['dataset'].replace('xyguassian', 'synCausal_20000')
df['dataset'] = df['dataset'].replace('xyguassian1000', 'synCausal_1000')
df['dataset'] = df['dataset'].replace('xyguassian200', 'synCausal_200')
df['dataset'] = df['dataset'].replace('xyguassian5000', 'synCausal_5000')
df['dataset'] = df['dataset'].replace('yxguassian5000', 'synAnticausal_5000')
df['dataset'] = df['dataset'].replace('yxguassian1000', 'synAnticausal_1000')
df['dataset'] = df['dataset'].replace('yxguassian200', 'synAntiausal_200')
df['dataset'] = df['dataset'].replace('yxguassian', 'synAnticausal_20000')
# df['dataset'] = df['dataset'].replace('krkp', 'KrKp')
#df['dataset'] = df['dataset'].replace('splice', 'Splice')
#df['dataset'] = df['dataset'].replace('secstr', 'SecStr')

# plot the data x is threshold, y is p_value, color is combined column, connected with lines
#sns.scatterplot(x="threshold", y="p_value", hue="dataset", data=df,  palette='bright', s=1, alpha=0.5, linewidth=0,legend=False)
sns.lineplot(x="threshold", y="p_value", hue="dataset", data=df, legend="auto",palette='bright',errorbar=('ci',95), err_style='band', markers=True, dashes=False, markersize=3, alpha=0.5, linewidth=0.5)

# plot a horizontal line at p_value = 0.025
plt.axhline(y=0.025, color='r', linestyle='--')

# move legend outside the plot, make the legend font smaller
plt.legend(loc='upper right',fontsize=12,bbox_to_anchor=(0.95, 0.95))
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=14)
# rename legend for scatterplot
#plt.legend(labels=['1',"",'2'])
# rename x and y axis

plt.xlabel('Absolute Value of Threshold')

plt.ylabel('P-value')
# add annotation to the red dash line with an arrow pointing to it (red)
plt.xlim(0,0.105)
plt.ylim(-0.1,1.05)
#plt.annotate('P-value=0.025', xy=(0.055, 0.045), xytext=(0.045, 0.225), arrowprops=dict(facecolor='red', shrink=0.05))
plt.savefig('./results/pdf/pvalue_threshold_xyguassian.pdf',bbox_inches='tight')
plt.figure(figsize=(20, 10))

# %%
df
# Out:
#      Unnamed: 0 dataset noise_type  initial_noise     slope    stderr  \
# 132         NaN    KrKp   instance            0.0  0.019484  0.004152
# 133         NaN    KrKp   instance            0.1  0.011085  0.006909
# 134         NaN    KrKp   instance            0.2  0.017449  0.006222
# 135         NaN    KrKp   instance            0.3  0.022092  0.006287
# 136         NaN    KrKp        sym            0.0  0.003417  0.004128
# 137         NaN    KrKp        sym            0.1  0.015363  0.003249
# 138         NaN    KrKp        sym            0.2  0.016249  0.002111
# 139         NaN    KrKp        sym            0.3  0.011920  0.005958
# 140         NaN    KrKp       pair            0.0  0.003417  0.004128
# 141         NaN    KrKp       pair            0.1  0.015363  0.003249
# 142         NaN    KrKp       pair            0.2  0.016249  0.002111
# 143         NaN    KrKp       pair            0.3  0.011920  0.005958
#
#          corr  threshold  p_value            combine
# 132  0.871103        0.1      0.0  krkp_instance_0.0
# 133  0.518551        0.1      0.0  krkp_instance_0.1
# 134  0.727410        0.1      0.0  krkp_instance_0.2
# 135  0.798868        0.1      0.0  krkp_instance_0.3
# 136  0.298559        0.1      0.0       krkp_sym_0.0
# 137  0.872690        0.1      0.0       krkp_sym_0.1
# 138  0.945674        0.1      0.0       krkp_sym_0.2
# 139  0.603109        0.1      0.0       krkp_sym_0.3
# 140  0.298559        0.1      0.0      krkp_pair_0.0
# 141  0.872690        0.1      0.0      krkp_pair_0.1
# 142  0.945674        0.1      0.0      krkp_pair_0.2
# 143  0.603109        0.1      0.0      krkp_pair_0.3

# %% [markdown]
# # overleaf table generator

# %%
df3=corr_table_total3.copy()
df3['slope']=df3['slope'].round(4).astype(str)
df3['stderr']=df3['stderr'].round(4).astype(str)

df3['output'] = "\makecell{"+df3['slope'] +'$\pm$'+ df3['stderr']+ '\\\\ p='+df3['p_value']+"} &"

df3=df3.drop(['slope','stderr','p_value','threshold','corr','combine'],axis=1)
df4=df3.groupby(['dataset','noise_type','initial_noise']).first().reset_index()
# convert df4 to multiindex
df4 = df4.set_index(['dataset','noise_type','initial_noise'])
# exchange columns and rows
df4 = df4.unstack(level=1)
df4 =df4.unstack(level=1)
df4.to_csv('./results/csv/table/corr_OVERLEAF_instance.csv')
df4
# Out:
#                                                    output  \
# noise_type                                       instance
# initial_noise                                         0.0
# dataset
# balancescale    \makecell{0.1783$\pm$0.0048\\ p=1.0000} &
# breastcancer    \makecell{0.0747$\pm$0.0055\\ p=0.0009} &
# iris            \makecell{0.8478$\pm$0.0147\\ p=1.0000} &
# krkp            \makecell{0.0088$\pm$0.0017\\ p=0.0000} &
# letter          \makecell{0.2163$\pm$0.0024\\ p=1.0000} &
# mushroom         \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment         \makecell{0.4456$\pm$0.0095\\ p=1.0000} &
# sonar             \makecell{0.0979$\pm$0.01\\ p=0.4204} &
# splice          \makecell{0.0273$\pm$0.0018\\ p=0.0000} &
# vowel            \makecell{0.082$\pm$0.0026\\ p=0.0001} &
# waveform        \makecell{0.2769$\pm$0.0038\\ p=1.0000} &
# wdbc            \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian     \makecell{-0.0045$\pm$0.0024\\ p=0.0000} &
# yxguassian      \makecell{0.7081$\pm$0.0086\\ p=1.0000} &
#
#                                                            \
# noise_type
# initial_noise                                         0.1
# dataset
# balancescale    \makecell{0.1783$\pm$0.0048\\ p=1.0000} &
# breastcancer    \makecell{0.0747$\pm$0.0055\\ p=0.0009} &
# iris            \makecell{0.8478$\pm$0.0147\\ p=1.0000} &
# krkp           \makecell{-0.0081$\pm$0.0023\\ p=0.0000} &
# letter          \makecell{0.2148$\pm$0.0024\\ p=1.0000} &
# mushroom         \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment         \makecell{0.4456$\pm$0.0095\\ p=1.0000} &
# sonar             \makecell{0.0979$\pm$0.01\\ p=0.4204} &
# splice          \makecell{0.0272$\pm$0.0021\\ p=0.0000} &
# vowel            \makecell{0.087$\pm$0.0022\\ p=0.0002} &
# waveform        \makecell{0.2769$\pm$0.0038\\ p=1.0000} &
# wdbc            \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian     \makecell{-0.0042$\pm$0.0016\\ p=0.0000} &
# yxguassian      \makecell{0.7081$\pm$0.0086\\ p=1.0000} &
#
#                                                            \
# noise_type
# initial_noise                                         0.2
# dataset
# balancescale    \makecell{0.1783$\pm$0.0048\\ p=1.0000} &
# breastcancer    \makecell{0.0747$\pm$0.0055\\ p=0.0009} &
# iris            \makecell{0.8478$\pm$0.0147\\ p=1.0000} &
# krkp           \makecell{-0.0081$\pm$0.0023\\ p=0.0000} &
# letter          \makecell{0.2168$\pm$0.0024\\ p=1.0000} &
# mushroom         \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment         \makecell{0.4376$\pm$0.0123\\ p=1.0000} &
# sonar           \makecell{0.0357$\pm$0.0103\\ p=0.0001} &
# splice          \makecell{0.0267$\pm$0.0018\\ p=0.0000} &
# vowel           \makecell{0.0871$\pm$0.0021\\ p=0.0001} &
# waveform         \makecell{0.303$\pm$0.0032\\ p=1.0000} &
# wdbc            \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian     \makecell{-0.0042$\pm$0.0016\\ p=0.0000} &
# yxguassian      \makecell{0.7081$\pm$0.0086\\ p=1.0000} &
#
#                                                            \
# noise_type
# initial_noise                                         0.3
# dataset
# balancescale    \makecell{0.1695$\pm$0.0045\\ p=1.0000} &
# breastcancer    \makecell{0.0279$\pm$0.0069\\ p=0.0000} &
# iris            \makecell{0.8478$\pm$0.0147\\ p=1.0000} &
# krkp           \makecell{-0.0081$\pm$0.0023\\ p=0.0000} &
# letter          \makecell{0.2119$\pm$0.0024\\ p=1.0000} &
# mushroom         \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment         \makecell{0.4368$\pm$0.0125\\ p=1.0000} &
# sonar           \makecell{0.0918$\pm$0.0066\\ p=0.1264} &
# splice          \makecell{0.0276$\pm$0.0021\\ p=0.0000} &
# vowel           \makecell{0.0785$\pm$0.0012\\ p=0.0000} &
# waveform         \makecell{0.303$\pm$0.0032\\ p=1.0000} &
# wdbc            \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian     \makecell{-0.0047$\pm$0.0004\\ p=0.0000} &
# yxguassian      \makecell{0.7081$\pm$0.0086\\ p=1.0000} &
#
#                                                           \
# noise_type                                          pair
# initial_noise                                        0.0
# dataset
# balancescale   \makecell{0.2037$\pm$0.0045\\ p=1.0000} &
# breastcancer   \makecell{0.0819$\pm$0.0062\\ p=0.0096} &
# iris           \makecell{0.8444$\pm$0.0189\\ p=1.0000} &
# krkp           \makecell{0.0104$\pm$0.0012\\ p=0.0000} &
# letter          \makecell{0.221$\pm$0.0025\\ p=1.0000} &
# mushroom        \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment        \makecell{0.4923$\pm$0.0135\\ p=1.0000} &
# sonar          \makecell{0.1138$\pm$0.0091\\ p=0.9150} &
# splice         \makecell{0.0713$\pm$0.0014\\ p=0.0000} &
# vowel          \makecell{0.0866$\pm$0.0017\\ p=0.0000} &
# waveform       \makecell{0.2485$\pm$0.0041\\ p=1.0000} &
# wdbc           \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian     \makecell{0.0041$\pm$0.0006\\ p=0.0000} &
# yxguassian      \makecell{0.708$\pm$0.0086\\ p=1.0000} &
#
#                                                           \
# noise_type
# initial_noise                                        0.1
# dataset
# balancescale   \makecell{0.2037$\pm$0.0045\\ p=1.0000} &
# breastcancer    \makecell{0.0372$\pm$0.009\\ p=0.0001} &
# iris           \makecell{0.8478$\pm$0.0147\\ p=1.0000} &
# krkp           \makecell{0.0114$\pm$0.0016\\ p=0.0000} &
# letter         \makecell{0.2174$\pm$0.0026\\ p=1.0000} &
# mushroom        \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment        \makecell{0.4844$\pm$0.0126\\ p=1.0000} &
# sonar          \makecell{0.0941$\pm$0.0096\\ p=0.2775} &
# splice         \makecell{0.0483$\pm$0.0016\\ p=0.0000} &
# vowel          \makecell{0.0863$\pm$0.0023\\ p=0.0002} &
# waveform        \makecell{0.237$\pm$0.0032\\ p=1.0000} &
# wdbc           \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian      \makecell{0.002$\pm$0.0016\\ p=0.0000} &
# yxguassian      \makecell{0.708$\pm$0.0086\\ p=1.0000} &
#
#                                                            \
# noise_type
# initial_noise                                         0.2
# dataset
# balancescale    \makecell{0.2475$\pm$0.0045\\ p=1.0000} &
# breastcancer    \makecell{0.0167$\pm$0.0132\\ p=0.0001} &
# iris            \makecell{0.8478$\pm$0.0147\\ p=1.0000} &
# krkp            \makecell{0.0098$\pm$0.0021\\ p=0.0000} &
# letter          \makecell{0.2192$\pm$0.0023\\ p=1.0000} &
# mushroom         \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment         \makecell{0.4659$\pm$0.0093\\ p=1.0000} &
# sonar          \makecell{-0.0348$\pm$0.0068\\ p=0.0000} &
# splice          \makecell{0.0595$\pm$0.0013\\ p=0.0000} &
# vowel           \makecell{0.0755$\pm$0.0026\\ p=0.0000} &
# waveform        \makecell{0.2371$\pm$0.0032\\ p=1.0000} &
# wdbc            \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian     \makecell{-0.0017$\pm$0.0016\\ p=0.0000} &
# yxguassian       \makecell{0.708$\pm$0.0086\\ p=1.0000} &
#
#                                                           \
# noise_type
# initial_noise                                        0.3
# dataset
# balancescale   \makecell{0.1999$\pm$0.0046\\ p=1.0000} &
# breastcancer   \makecell{0.0167$\pm$0.0132\\ p=0.0001} &
# iris           \makecell{0.8478$\pm$0.0147\\ p=1.0000} &
# krkp           \makecell{0.0128$\pm$0.0021\\ p=0.0000} &
# letter         \makecell{0.2064$\pm$0.0024\\ p=1.0000} &
# mushroom        \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment        \makecell{0.4398$\pm$0.0111\\ p=1.0000} &
# sonar          \makecell{-0.088$\pm$0.0063\\ p=0.0459} &
# splice          \makecell{0.045$\pm$0.0024\\ p=0.0000} &
# vowel           \makecell{0.073$\pm$0.0022\\ p=0.0000} &
# waveform       \makecell{0.2371$\pm$0.0032\\ p=1.0000} &
# wdbc           \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian     \makecell{0.0003$\pm$0.0006\\ p=0.0000} &
# yxguassian      \makecell{0.708$\pm$0.0086\\ p=1.0000} &
#
#                                                           \
# noise_type                                           sym
# initial_noise                                        0.0
# dataset
# balancescale   \makecell{0.2037$\pm$0.0045\\ p=1.0000} &
# breastcancer   \makecell{0.0747$\pm$0.0055\\ p=0.0009} &
# iris           \makecell{0.8478$\pm$0.0147\\ p=1.0000} &
# krkp           \makecell{0.0104$\pm$0.0012\\ p=0.0000} &
# letter          \makecell{0.221$\pm$0.0025\\ p=1.0000} &
# mushroom        \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment         \makecell{0.494$\pm$0.0111\\ p=1.0000} &
# sonar          \makecell{0.0941$\pm$0.0096\\ p=0.2775} &
# splice         \makecell{0.0562$\pm$0.0017\\ p=0.0000} &
# vowel          \makecell{0.0852$\pm$0.0028\\ p=0.0004} &
# waveform       \makecell{0.2485$\pm$0.0041\\ p=1.0000} &
# wdbc           \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian     \makecell{0.0041$\pm$0.0006\\ p=0.0000} &
# yxguassian      \makecell{0.708$\pm$0.0086\\ p=1.0000} &
#
#                                                           \
# noise_type
# initial_noise                                        0.1
# dataset
# balancescale   \makecell{0.2037$\pm$0.0045\\ p=1.0000} &
# breastcancer    \makecell{0.0372$\pm$0.009\\ p=0.0001} &
# iris           \makecell{0.8478$\pm$0.0147\\ p=1.0000} &
# krkp           \makecell{0.0114$\pm$0.0016\\ p=0.0000} &
# letter         \makecell{0.2165$\pm$0.0024\\ p=1.0000} &
# mushroom        \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment          \makecell{0.4776$\pm$0.01\\ p=1.0000} &
# sonar          \makecell{0.0941$\pm$0.0096\\ p=0.2775} &
# splice          \makecell{0.0372$\pm$0.002\\ p=0.0000} &
# vowel          \makecell{0.0892$\pm$0.0028\\ p=0.0023} &
# waveform       \makecell{0.2301$\pm$0.0036\\ p=1.0000} &
# wdbc           \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian      \makecell{0.002$\pm$0.0016\\ p=0.0000} &
# yxguassian      \makecell{0.708$\pm$0.0086\\ p=1.0000} &
#
#                                                            \
# noise_type
# initial_noise                                         0.2
# dataset
# balancescale    \makecell{0.2475$\pm$0.0045\\ p=1.0000} &
# breastcancer    \makecell{0.0167$\pm$0.0132\\ p=0.0001} &
# iris            \makecell{0.8478$\pm$0.0147\\ p=1.0000} &
# krkp            \makecell{0.0098$\pm$0.0021\\ p=0.0000} &
# letter          \makecell{0.2198$\pm$0.0025\\ p=1.0000} &
# mushroom         \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment         \makecell{0.4573$\pm$0.0113\\ p=1.0000} &
# sonar          \makecell{-0.0348$\pm$0.0068\\ p=0.0000} &
# splice            \makecell{0.069$\pm$0.002\\ p=0.0000} &
# vowel           \makecell{0.0935$\pm$0.0018\\ p=0.0040} &
# waveform        \makecell{0.2485$\pm$0.0041\\ p=1.0000} &
# wdbc            \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian     \makecell{-0.0017$\pm$0.0016\\ p=0.0000} &
# yxguassian       \makecell{0.708$\pm$0.0086\\ p=1.0000} &
#
#
# noise_type
# initial_noise                                        0.3
# dataset
# balancescale   \makecell{0.1949$\pm$0.0046\\ p=1.0000} &
# breastcancer   \makecell{0.0167$\pm$0.0132\\ p=0.0001} &
# iris           \makecell{0.8478$\pm$0.0147\\ p=1.0000} &
# krkp           \makecell{0.0128$\pm$0.0021\\ p=0.0000} &
# letter         \makecell{0.2206$\pm$0.0024\\ p=1.0000} &
# mushroom        \makecell{0.656$\pm$0.0079\\ p=1.0000} &
# segment        \makecell{0.4816$\pm$0.0106\\ p=1.0000} &
# sonar          \makecell{-0.088$\pm$0.0063\\ p=0.0459} &
# splice         \makecell{0.0446$\pm$0.0019\\ p=0.0000} &
# vowel          \makecell{0.0906$\pm$0.0023\\ p=0.0019} &
# waveform       \makecell{0.2485$\pm$0.0041\\ p=1.0000} &
# wdbc           \makecell{0.6809$\pm$0.0121\\ p=1.0000} &
# xyguassian     \makecell{0.0003$\pm$0.0006\\ p=0.0000} &
# yxguassian      \makecell{0.708$\pm$0.0086\\ p=1.0000} &

# %%
#plot threshold vs p-value for each dataset
# dataset_names = corr_table_total['dataset'].unique()
# noise_types = corr_table_total['noise_type'].unique()
# initial_noise_list = corr_table_total['initial_noise'].unique()


corr_table_total['combine']=corr_table_total['dataset']+'_'+corr_table_total['noise_type']+'_'+corr_table_total['initial_noise'].astype(str)
#corr_table_total.set_index(['dataset', 'noise_type', 'initial_noise'], inplace=True)
#corr_table_total.groupby('combine').plot(x='threshold', y='p_value', kind='line', title='threshold vs p-value')
# Create the plot
fig, ax = plt.subplots()
for combination, group in corr_table_total.groupby(level=0):
    ax.plot(group['threshold'], group['p_value'], label=combination)
ax.set_xlabel('Threshold')
ax.set_ylabel('p-value')

# Show the plot
plt.show()

# %%
corr_table_total['combined']= corr_table_total['dataset']+'_'+corr_table_total['noise_type']+'_'+corr_table_total['initial_noise'].astype(str)
x=corr_table_total['threshold']
y=corr_table_total['p_value']
col=corr_table_total['combined']

# %%
#plot threshold vs p-value for each dataset
corr_table_total.groupby(['dataset','noise_type','initial_noise']).plot(x='threshold', y='p_value', style='o')

# %%
#plot threshold vs p-value for each dataset
corr_table_total.groupby(['dataset','noise_type','initial_noise']).plot(x='threshold', y='p_value', style='o')

# %%
#plot threshold vs p-value for each dataset
corr_table_total.groupby(['dataset','noise_type','initial_noise']).plot(x='threshold', y='p_value', style='o')

# %%
corr_table_total_groupby
# Out:
#         dataset noise_type  initial_noise  threshold      corr       p_value
# 0          krkp   instance            0.0      0.005  0.871103  9.958926e-01
# 1          krkp   instance            0.0      0.010  0.871103  9.741383e-01
# 2          krkp   instance            0.0      0.020  0.871103  4.520368e-01
# 3          krkp   instance            0.0      0.030  0.871103  1.754342e-02
# 4          krkp   instance            0.0      0.040  0.871103  5.662736e-04
# ..          ...        ...            ...        ...       ...           ...
# 157  xyguassian        sym            0.4      0.010  0.437518  1.545184e-04
# 158  xyguassian        sym            0.4      0.020  0.437518  4.687195e-07
# 159  xyguassian        sym            0.4      0.030  0.437518  1.555860e-08
# 160  xyguassian        sym            0.4      0.040  0.437518  1.418862e-09
# 161  xyguassian        sym            0.4      0.050  0.437518  2.242628e-10
#
# [162 rows x 6 columns]

# %%
# Out:
#    dataset noise_type  initial_noise      corr  threshold       p_value
# 0     krkp   instance            0.0  0.871103       0.05  3.995215e-05
# 1     krkp   instance            0.2  0.727410       0.05  3.954928e-04
# 2     krkp   instance            0.4  0.899141       0.05  4.294168e-04
# 3     krkp        sym            0.0  0.298559       0.05  1.710691e-06
# 4     krkp        sym            0.2  0.945674       0.05  1.175942e-07
# 5     krkp        sym            0.4  0.877720       0.05  6.614475e-07
# 6     krkp       pair            0.0  0.298559       0.05  1.710691e-06
# 7     krkp       pair            0.2  0.945674       0.05  1.175942e-07
# 8     krkp       pair            0.4  0.877720       0.05  6.614475e-07
# 9     krkp   instance            0.0  0.871103       0.04  5.662736e-04
# 10    krkp   instance            0.2  0.727410       0.04  3.368561e-03
# 11    krkp   instance            0.4  0.899141       0.04  7.976266e-03
# 12    krkp        sym            0.0  0.298559       0.04  1.038179e-05
# 13    krkp        sym            0.2  0.945674       0.04  1.752064e-06
# 14    krkp        sym            0.4  0.877720       0.04  7.531248e-06
# 15    krkp       pair            0.0  0.298559       0.04  1.038179e-05
# 16    krkp       pair            0.2  0.945674       0.04  1.752064e-06
# 17    krkp       pair            0.4  0.877720       0.04  7.531248e-06
# 18    krkp   instance            0.0  0.871103       0.03  1.754342e-02
# 19    krkp   instance            0.2  0.727410       0.03  3.919163e-02

# %%
corr_table
# Out:
#   dataset noise_type  initial_noise      corr  threshold   p_value
# 0    krkp   instance            0.0  0.871103      0.005  0.995893
# 1    krkp   instance            0.2  0.727410      0.005  0.959803
# 2    krkp   instance            0.4  0.899141      0.005  0.998819
# 3    krkp        sym            0.0  0.298559      0.005  0.355668
# 4    krkp        sym            0.2  0.945674      0.005  0.999648
# 5    krkp        sym            0.4  0.877720      0.005  0.992481
# 6    krkp       pair            0.0  0.298559      0.005  0.355668
# 7    krkp       pair            0.2  0.945674      0.005  0.999648
# 8    krkp       pair            0.4  0.877720      0.005  0.992481

# %%
noise_type_list = ["instance","sym"]
initial_noise_list = [0.1,0.2]
df = pd.read_csv("./results/xyguassian_groupby.csv")

fig, axs = plt.subplots(2,2, figsize=(10, 10))
num_plots = len(noise_type_list)*len(initial_noise_list)
nrows = 2
ncols = int(num_plots/nrows)
i=0
j=0
for noise_type in noise_type_list:
    for initial_noise in initial_noise_list:
        
        df_temp = df[(df['noise_type']==noise_type) & (df['initial_noise']==initial_noise)]
        x=df_temp['noise_rate']
        y =df_temp['mean']
        y_std = df_temp['std']
        
        # Define the confidence interval
        ci = 0.1 * y_std / y
        # calculate correlation coefficient
        corr = np.corrcoef(x, y)[0, 1]


        axs[i,j].scatter(x, y, label=noise_type)     
        axs[i,j].plot(x, y, '*', color='blue')
        axs[i,j].text(x=0.1, y=0.5,s='\n\nInitial noise rate:'+str(initial_noise)+'\n\nNoise type: '+ noise_type+'\n\n\u03C1: '+str(round(corr,2)), fontsize=12)
        axs[i,j].plot(x,y)
        axs[i,j].set_ylim(0,1)
        plt.xlabel('Noise Rate')
        plt.ylabel('Error Rate')
        # Plot the confidence interval
        axs[i,j].fill_between(x, (y-ci), (y+ci), color='blue', alpha=0.2)
        #axs[i,j].savefig('./results/xyguassian_'+noise_type+'_'+str(initial_noise)+'.png')
            
        j+=1
        if j==ncols:
            i+=1
            j=0
        
plt.savefig('./results/xyguassian.png')

# %%
# if dataset in "krkp", "balancescale", "splice", "xyguassian" then it is causal
df['causal'] = df['dataset'].apply(lambda x: 1 if x in ["krkp", "balancescale", "splice","xyguassian"] else 0)

df.to_csv('./results/results_method1_error_rate2.csv', index=False)

# %% [markdown]
# # New dataset

# %% [markdown]
# breast-cancer-wisconsin

# %%
df = pd.read_csv('./datasets/wdbc/wdbc.data',header=None)

# recode the class labels maelignant as 1 and benign as 0
df[1] = df[1].apply(lambda x: 1 if x=='M' else 0)
# drop the first column
df.drop(df.columns[0], axis=1, inplace=True)
# move the class label to the last column
# Out:
#      1      2      3       4       5        6        7        8        9   \
# 0     1  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010  0.14710
# 1     1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017
# 2     1  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790
# 3     1  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520
# 4     1  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800  0.10430
# ..   ..    ...    ...     ...     ...      ...      ...      ...      ...
# 564   1  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390  0.13890
# 565   1  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400  0.09791
# 566   1  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302
# 567   1  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140  0.15200
# 568   0   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000
#
#          10  ...      22     23      24      25       26       27      28  \
# 0    0.2419  ...  25.380  17.33  184.60  2019.0  0.16220  0.66560  0.7119
# 1    0.1812  ...  24.990  23.41  158.80  1956.0  0.12380  0.18660  0.2416
# 2    0.2069  ...  23.570  25.53  152.50  1709.0  0.14440  0.42450  0.4504
# 3    0.2597  ...  14.910  26.50   98.87   567.7  0.20980  0.86630  0.6869
# 4    0.1809  ...  22.540  16.67  152.20  1575.0  0.13740  0.20500  0.4000
# ..      ...  ...     ...    ...     ...     ...      ...      ...     ...
# 564  0.1726  ...  25.450  26.40  166.10  2027.0  0.14100  0.21130  0.4107
# 565  0.1752  ...  23.690  38.25  155.00  1731.0  0.11660  0.19220  0.3215
# 566  0.1590  ...  18.980  34.12  126.70  1124.0  0.11390  0.30940  0.3403
# 567  0.2397  ...  25.740  39.42  184.60  1821.0  0.16500  0.86810  0.9387
# 568  0.1587  ...   9.456  30.37   59.16   268.6  0.08996  0.06444  0.0000
#
#          29      30       31
# 0    0.2654  0.4601  0.11890
# 1    0.1860  0.2750  0.08902
# 2    0.2430  0.3613  0.08758
# 3    0.2575  0.6638  0.17300
# 4    0.1625  0.2364  0.07678
# ..      ...     ...      ...
# 564  0.2216  0.2060  0.07115
# 565  0.1628  0.2572  0.06637
# 566  0.1418  0.2218  0.07820
# 567  0.2650  0.4087  0.12400
# 568  0.0000  0.2871  0.07039
#
# [569 rows x 31 columns]
